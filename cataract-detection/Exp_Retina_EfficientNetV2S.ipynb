# %% [markdown]
# <a href="https://colab.research.google.com/github/sunfflur/frequency-learning/blob/master/cataract-detection/Exp_Retina_EfficientNetV2S.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EfficientNetV2S

# %% [markdown]
# #### Libraries Import

# %%
s = 23
import os
os.environ['PYTHONHASHSEED']=str(s)
import random
random.seed(s)
from numpy.random import seed
seed(s)
from tensorflow.random import set_seed
set_seed(s)

import PIL
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Layer, Dense, Conv1D, Dropout, MaxPooling2D, Flatten
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications.efficientnet_v2 import EfficientNetV2S
from tensorflow.keras.applications.efficientnet_v2 import preprocess_input
from tensorflow.keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
import seaborn as sn

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Sun Oct 30 21:06:38 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 27.3 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %% [markdown]
# #### Drive mount

# %%
### TESSSSSST ###

# !sudo add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !sudo apt-get update -qq 2>&1 > /dev/null
# !sudo apt -y install -qq google-drive-ocamlfuse 2>&1 > /dev/null
# !google-drive-ocamlfuse
# Out:
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: www-browser: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: links2: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: elinks: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: links: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: lynx: not found
# /usr/bin/xdg-open: 851: /usr/bin/xdg-open: w3m: not found
# xdg-open: no method available for opening 'https://accounts.google.com/o/oauth2/auth?client_id=564921029129.apps.googleusercontent.com&redirect_uri=https%3A%2F%2Fgd-ocaml-auth.appspot.com%2Foauth2callback&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force&state=A%2FDUl0iCDpXDjP30RcRmGeXaFXZlNzP0Pak2shvJB3Q'
# /bin/sh: 1: firefox: not found
# /bin/sh: 1: google-chrome: not found
# /bin/sh: 1: chromium-browser: not found
# /bin/sh: 1: open: not found
# Cannot retrieve auth tokens.
# Failure("Error opening URL:https://accounts.google.com/o/oauth2/auth?client_id=564921029129.apps.googleusercontent.com&redirect_uri=https%3A%2F%2Fgd-ocaml-auth.appspot.com%2Foauth2callback&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force&state=A%2FDUl0iCDpXDjP30RcRmGeXaFXZlNzP0Pak2shvJB3Q")

# %%
# !sudo apt-get install -qq w3m # to act as web browser 
# !xdg-settings set default-web-browser w3m.desktop # to set default browser
# %cd /content
# !mkdir drive
# %cd drive
# !mkdir MyDrive
# %cd ..
# %cd ..
# !google-drive-ocamlfuse /content/drive/MyDrive
# Out:
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package w3m.
# (Reading database ... 123947 files and directories currently installed.)
# Preparing to unpack .../w3m_0.5.3-36build1_amd64.deb ...
# Unpacking w3m (0.5.3-36build1) ...
# Setting up w3m (0.5.3-36build1) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# /content
# /content/drive
# /content
# /
# Access token retrieved correctly.

# %% [markdown]
# #### Data Load

# %%
### data loading ### 
path_train = '/content/drive/MyDrive/Mestrado/Datasets/retina/retina-dataset/retina_train.npy'
path_ytrain = '/content/drive/MyDrive/Mestrado/Datasets/retina/retina-dataset/retina_y_train.npy'
path_test = '/content/drive/MyDrive/Mestrado/Datasets/retina/retina-dataset/retina_test.npy'
path_ytest = '/content/drive/MyDrive/Mestrado/Datasets/retina/retina-dataset/retina_y_test.npy'

x_train, x_test = np.load(path_train), np.load(path_test)
y_train, y_test = np.load(path_ytrain), np.load(path_ytest)
#x_train, x_test = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1), x_test.reshape(x_test.shape[0], x_test.shape[1], x_test.shape[2], 1)

# adjust dimension and change from array to tensor + convert to 3 channel images
new_shape = (224,224)
x_train, x_test = tf.image.resize(x_train, new_shape), tf.image.resize(x_test, new_shape)
x_train, x_test = x_train*255, x_test*255
#x_train, x_test = tf.cast(x_train, dtype=tf.int32), tf.cast(x_test, dtype=tf.int32)
#x_train, x_test = tf.image.grayscale_to_rgb(x_train), tf.image.grayscale_to_rgb(x_test)
y_train, y_test = tf.stack(to_categorical(y_train)), tf.stack(to_categorical(y_test))
#y_train, y_test = tf.cast(y_train, dtype=tf.int32), tf.cast(y_test, dtype=tf.int32)

# %% [markdown]
# #### Pre-trained Model

# %%
# prepare the image for the EfficientNetV2S model
x_train1 = preprocess_input(x_train)
x_test1 = preprocess_input(x_test)

# %%
def pre_trained_model(input_shape, n_classes, optimizer, fine_tune=0):
    """
    input_shape: tuple - the shape of input images (width, height, channels)
    n_classes: int - number of classes for the output layer
    optimizer: string - instantiated optimizer to use for training.
    fine_tune: int - The number of pre-trained layers to unfreeze. 
               0 = all pretrained layers will freeze during training
    """
    
    # Pretrained convolutional layers are loaded using the Imagenet weights.
    # Include_top is set to False, in order to exclude the model's fully-connected layers.
    efficientnetv2s_model = EfficientNetV2S(include_top=True,
                     weights='imagenet', 
                     input_shape=input_shape)
    
    # Defines how many layers to freeze during training.
    # Layers in the convolutional base are switched from trainable to non-trainable
    # depending on the size of the fine-tuning parameter.
    
    if fine_tune > 0:
        for layer in efficientnetv2s_model.layers[:-fine_tune]:
            layer.trainable = False
    else:
        for layer in efficientnetv2s_model.layers:
            layer.trainable = False
    
    '''
    # Turn all the layers trainable.

    for layer in efficientnetv2s_model.layers:
      layer.trainable = True
    '''
    # Create a new 'top' of the model (i.e. fully-connected layers).
    # This is 'bootstrapping' a new top_model onto the pretrained layers.
    top_model = efficientnetv2s_model.layers[-2].output
    #top_model = Flatten(name="flatten")(top_model)
    #top_model = Dense(4096, activation='relu')(top_model)
    #top_model = Dense(128, activation='relu')(top_model)
    #top_model = Dropout(0.25)(top_model)
    output_layer = Dense(n_classes, activation='softmax', name='my_predictions')(top_model)
    
    # Group the convolutional base and new output into a Model object.
    model = Model(inputs=efficientnetv2s_model.input, outputs=output_layer)

    # Compiles the model for training.
    model.compile(optimizer=optimizer, 
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    
    return model

# %%
tf.random.set_seed(s) #s
opt = Adam(learning_rate=0.0001)
EfficientNetV2S_model = pre_trained_model(input_shape=(384,384,3), n_classes=2, optimizer=opt)

# %%
print(EfficientNetV2S_model.summary())
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 384, 384, 3  0           []
#                                 )]
#
#  rescaling_1 (Rescaling)        (None, 384, 384, 3)  0           ['input_2[0][0]']
#
#  stem_conv (Conv2D)             (None, 192, 192, 24  648         ['rescaling_1[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 192, 192, 24  96          ['stem_conv[0][0]']
#                                 )
#
#  stem_activation (Activation)   (None, 192, 192, 24  0           ['stem_bn[0][0]']
#                                 )
#
#  block1a_project_conv (Conv2D)  (None, 192, 192, 24  5184        ['stem_activation[0][0]']
#                                 )
#
#  block1a_project_bn (BatchNorma  (None, 192, 192, 24  96         ['block1a_project_conv[0][0]']
#  lization)                      )
#
#  block1a_project_activation (Ac  (None, 192, 192, 24  0          ['block1a_project_bn[0][0]']
#  tivation)                      )
#
#  block1a_add (Add)              (None, 192, 192, 24  0           ['block1a_project_activation[0][0
#                                 )                                ]',
#                                                                   'stem_activation[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, 192, 192, 24  5184        ['block1a_add[0][0]']
#                                 )
#
#  block1b_project_bn (BatchNorma  (None, 192, 192, 24  96         ['block1b_project_conv[0][0]']
#  lization)                      )
#
#  block1b_project_activation (Ac  (None, 192, 192, 24  0          ['block1b_project_bn[0][0]']
#  tivation)                      )
#
#  block1b_drop (Dropout)         (None, 192, 192, 24  0           ['block1b_project_activation[0][0
#                                 )                                ]']
#
#  block1b_add (Add)              (None, 192, 192, 24  0           ['block1b_drop[0][0]',
#                                 )                                 'block1a_add[0][0]']
#
#  block2a_expand_conv (Conv2D)   (None, 96, 96, 96)   20736       ['block1b_add[0][0]']
#
#  block2a_expand_bn (BatchNormal  (None, 96, 96, 96)  384         ['block2a_expand_conv[0][0]']
#  ization)
#
#  block2a_expand_activation (Act  (None, 96, 96, 96)  0           ['block2a_expand_bn[0][0]']
#  ivation)
#
#  block2a_project_conv (Conv2D)  (None, 96, 96, 48)   4608        ['block2a_expand_activation[0][0]
#                                                                  ']
#
#  block2a_project_bn (BatchNorma  (None, 96, 96, 48)  192         ['block2a_project_conv[0][0]']
#  lization)
#
#  block2b_expand_conv (Conv2D)   (None, 96, 96, 192)  82944       ['block2a_project_bn[0][0]']
#
#  block2b_expand_bn (BatchNormal  (None, 96, 96, 192)  768        ['block2b_expand_conv[0][0]']
#  ization)
#
#  block2b_expand_activation (Act  (None, 96, 96, 192)  0          ['block2b_expand_bn[0][0]']
#  ivation)
#
#  block2b_project_conv (Conv2D)  (None, 96, 96, 48)   9216        ['block2b_expand_activation[0][0]
#                                                                  ']
#
#  block2b_project_bn (BatchNorma  (None, 96, 96, 48)  192         ['block2b_project_conv[0][0]']
#  lization)
#
#  block2b_drop (Dropout)         (None, 96, 96, 48)   0           ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)              (None, 96, 96, 48)   0           ['block2b_drop[0][0]',
#                                                                   'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, 96, 96, 192)  82944       ['block2b_add[0][0]']
#
#  block2c_expand_bn (BatchNormal  (None, 96, 96, 192)  768        ['block2c_expand_conv[0][0]']
#  ization)
#
#  block2c_expand_activation (Act  (None, 96, 96, 192)  0          ['block2c_expand_bn[0][0]']
#  ivation)
#
#  block2c_project_conv (Conv2D)  (None, 96, 96, 48)   9216        ['block2c_expand_activation[0][0]
#                                                                  ']
#
#  block2c_project_bn (BatchNorma  (None, 96, 96, 48)  192         ['block2c_project_conv[0][0]']
#  lization)
#
#  block2c_drop (Dropout)         (None, 96, 96, 48)   0           ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)              (None, 96, 96, 48)   0           ['block2c_drop[0][0]',
#                                                                   'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2D)   (None, 96, 96, 192)  82944       ['block2c_add[0][0]']
#
#  block2d_expand_bn (BatchNormal  (None, 96, 96, 192)  768        ['block2d_expand_conv[0][0]']
#  ization)
#
#  block2d_expand_activation (Act  (None, 96, 96, 192)  0          ['block2d_expand_bn[0][0]']
#  ivation)
#
#  block2d_project_conv (Conv2D)  (None, 96, 96, 48)   9216        ['block2d_expand_activation[0][0]
#                                                                  ']
#
#  block2d_project_bn (BatchNorma  (None, 96, 96, 48)  192         ['block2d_project_conv[0][0]']
#  lization)
#
#  block2d_drop (Dropout)         (None, 96, 96, 48)   0           ['block2d_project_bn[0][0]']
#
#  block2d_add (Add)              (None, 96, 96, 48)   0           ['block2d_drop[0][0]',
#                                                                   'block2c_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 48, 48, 192)  82944       ['block2d_add[0][0]']
#
#  block3a_expand_bn (BatchNormal  (None, 48, 48, 192)  768        ['block3a_expand_conv[0][0]']
#  ization)
#
#  block3a_expand_activation (Act  (None, 48, 48, 192)  0          ['block3a_expand_bn[0][0]']
#  ivation)
#
#  block3a_project_conv (Conv2D)  (None, 48, 48, 64)   12288       ['block3a_expand_activation[0][0]
#                                                                  ']
#
#  block3a_project_bn (BatchNorma  (None, 48, 48, 64)  256         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 48, 48, 256)  147456      ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 48, 48, 256)  1024       ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 48, 48, 256)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_project_conv (Conv2D)  (None, 48, 48, 64)   16384       ['block3b_expand_activation[0][0]
#                                                                  ']
#
#  block3b_project_bn (BatchNorma  (None, 48, 48, 64)  256         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (Dropout)         (None, 48, 48, 64)   0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 48, 48, 64)   0           ['block3b_drop[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2D)   (None, 48, 48, 256)  147456      ['block3b_add[0][0]']
#
#  block3c_expand_bn (BatchNormal  (None, 48, 48, 256)  1024       ['block3c_expand_conv[0][0]']
#  ization)
#
#  block3c_expand_activation (Act  (None, 48, 48, 256)  0          ['block3c_expand_bn[0][0]']
#  ivation)
#
#  block3c_project_conv (Conv2D)  (None, 48, 48, 64)   16384       ['block3c_expand_activation[0][0]
#                                                                  ']
#
#  block3c_project_bn (BatchNorma  (None, 48, 48, 64)  256         ['block3c_project_conv[0][0]']
#  lization)
#
#  block3c_drop (Dropout)         (None, 48, 48, 64)   0           ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)              (None, 48, 48, 64)   0           ['block3c_drop[0][0]',
#                                                                   'block3b_add[0][0]']
#
#  block3d_expand_conv (Conv2D)   (None, 48, 48, 256)  147456      ['block3c_add[0][0]']
#
#  block3d_expand_bn (BatchNormal  (None, 48, 48, 256)  1024       ['block3d_expand_conv[0][0]']
#  ization)
#
#  block3d_expand_activation (Act  (None, 48, 48, 256)  0          ['block3d_expand_bn[0][0]']
#  ivation)
#
#  block3d_project_conv (Conv2D)  (None, 48, 48, 64)   16384       ['block3d_expand_activation[0][0]
#                                                                  ']
#
#  block3d_project_bn (BatchNorma  (None, 48, 48, 64)  256         ['block3d_project_conv[0][0]']
#  lization)
#
#  block3d_drop (Dropout)         (None, 48, 48, 64)   0           ['block3d_project_bn[0][0]']
#
#  block3d_add (Add)              (None, 48, 48, 64)   0           ['block3d_drop[0][0]',
#                                                                   'block3c_add[0][0]']
#
#  block4a_expand_conv (Conv2D)   (None, 48, 48, 256)  16384       ['block3d_add[0][0]']
#
#  block4a_expand_bn (BatchNormal  (None, 48, 48, 256)  1024       ['block4a_expand_conv[0][0]']
#  ization)
#
#  block4a_expand_activation (Act  (None, 48, 48, 256)  0          ['block4a_expand_bn[0][0]']
#  ivation)
#
#  block4a_dwconv2 (DepthwiseConv  (None, 24, 24, 256)  2304       ['block4a_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4a_bn (BatchNormalization  (None, 24, 24, 256)  1024       ['block4a_dwconv2[0][0]']
#  )
#
#  block4a_activation (Activation  (None, 24, 24, 256)  0          ['block4a_bn[0][0]']
#  )
#
#  block4a_se_squeeze (GlobalAver  (None, 256)         0           ['block4a_activation[0][0]']
#  agePooling2D)
#
#  block4a_se_reshape (Reshape)   (None, 1, 1, 256)    0           ['block4a_se_squeeze[0][0]']
#
#  block4a_se_reduce (Conv2D)     (None, 1, 1, 16)     4112        ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)     (None, 1, 1, 256)    4352        ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multiply)   (None, 24, 24, 256)  0           ['block4a_activation[0][0]',
#                                                                   'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv2D)  (None, 24, 24, 128)  32768       ['block4a_se_excite[0][0]']
#
#  block4a_project_bn (BatchNorma  (None, 24, 24, 128)  512        ['block4a_project_conv[0][0]']
#  lization)
#
#  block4b_expand_conv (Conv2D)   (None, 24, 24, 512)  65536       ['block4a_project_bn[0][0]']
#
#  block4b_expand_bn (BatchNormal  (None, 24, 24, 512)  2048       ['block4b_expand_conv[0][0]']
#  ization)
#
#  block4b_expand_activation (Act  (None, 24, 24, 512)  0          ['block4b_expand_bn[0][0]']
#  ivation)
#
#  block4b_dwconv2 (DepthwiseConv  (None, 24, 24, 512)  4608       ['block4b_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4b_bn (BatchNormalization  (None, 24, 24, 512)  2048       ['block4b_dwconv2[0][0]']
#  )
#
#  block4b_activation (Activation  (None, 24, 24, 512)  0          ['block4b_bn[0][0]']
#  )
#
#  block4b_se_squeeze (GlobalAver  (None, 512)         0           ['block4b_activation[0][0]']
#  agePooling2D)
#
#  block4b_se_reshape (Reshape)   (None, 1, 1, 512)    0           ['block4b_se_squeeze[0][0]']
#
#  block4b_se_reduce (Conv2D)     (None, 1, 1, 32)     16416       ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)     (None, 1, 1, 512)    16896       ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multiply)   (None, 24, 24, 512)  0           ['block4b_activation[0][0]',
#                                                                   'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv2D)  (None, 24, 24, 128)  65536       ['block4b_se_excite[0][0]']
#
#  block4b_project_bn (BatchNorma  (None, 24, 24, 128)  512        ['block4b_project_conv[0][0]']
#  lization)
#
#  block4b_drop (Dropout)         (None, 24, 24, 128)  0           ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)              (None, 24, 24, 128)  0           ['block4b_drop[0][0]',
#                                                                   'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2D)   (None, 24, 24, 512)  65536       ['block4b_add[0][0]']
#
#  block4c_expand_bn (BatchNormal  (None, 24, 24, 512)  2048       ['block4c_expand_conv[0][0]']
#  ization)
#
#  block4c_expand_activation (Act  (None, 24, 24, 512)  0          ['block4c_expand_bn[0][0]']
#  ivation)
#
#  block4c_dwconv2 (DepthwiseConv  (None, 24, 24, 512)  4608       ['block4c_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4c_bn (BatchNormalization  (None, 24, 24, 512)  2048       ['block4c_dwconv2[0][0]']
#  )
#
#  block4c_activation (Activation  (None, 24, 24, 512)  0          ['block4c_bn[0][0]']
#  )
#
#  block4c_se_squeeze (GlobalAver  (None, 512)         0           ['block4c_activation[0][0]']
#  agePooling2D)
#
#  block4c_se_reshape (Reshape)   (None, 1, 1, 512)    0           ['block4c_se_squeeze[0][0]']
#
#  block4c_se_reduce (Conv2D)     (None, 1, 1, 32)     16416       ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)     (None, 1, 1, 512)    16896       ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multiply)   (None, 24, 24, 512)  0           ['block4c_activation[0][0]',
#                                                                   'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv2D)  (None, 24, 24, 128)  65536       ['block4c_se_excite[0][0]']
#
#  block4c_project_bn (BatchNorma  (None, 24, 24, 128)  512        ['block4c_project_conv[0][0]']
#  lization)
#
#  block4c_drop (Dropout)         (None, 24, 24, 128)  0           ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)              (None, 24, 24, 128)  0           ['block4c_drop[0][0]',
#                                                                   'block4b_add[0][0]']
#
#  block4d_expand_conv (Conv2D)   (None, 24, 24, 512)  65536       ['block4c_add[0][0]']
#
#  block4d_expand_bn (BatchNormal  (None, 24, 24, 512)  2048       ['block4d_expand_conv[0][0]']
#  ization)
#
#  block4d_expand_activation (Act  (None, 24, 24, 512)  0          ['block4d_expand_bn[0][0]']
#  ivation)
#
#  block4d_dwconv2 (DepthwiseConv  (None, 24, 24, 512)  4608       ['block4d_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4d_bn (BatchNormalization  (None, 24, 24, 512)  2048       ['block4d_dwconv2[0][0]']
#  )
#
#  block4d_activation (Activation  (None, 24, 24, 512)  0          ['block4d_bn[0][0]']
#  )
#
#  block4d_se_squeeze (GlobalAver  (None, 512)         0           ['block4d_activation[0][0]']
#  agePooling2D)
#
#  block4d_se_reshape (Reshape)   (None, 1, 1, 512)    0           ['block4d_se_squeeze[0][0]']
#
#  block4d_se_reduce (Conv2D)     (None, 1, 1, 32)     16416       ['block4d_se_reshape[0][0]']
#
#  block4d_se_expand (Conv2D)     (None, 1, 1, 512)    16896       ['block4d_se_reduce[0][0]']
#
#  block4d_se_excite (Multiply)   (None, 24, 24, 512)  0           ['block4d_activation[0][0]',
#                                                                   'block4d_se_expand[0][0]']
#
#  block4d_project_conv (Conv2D)  (None, 24, 24, 128)  65536       ['block4d_se_excite[0][0]']
#
#  block4d_project_bn (BatchNorma  (None, 24, 24, 128)  512        ['block4d_project_conv[0][0]']
#  lization)
#
#  block4d_drop (Dropout)         (None, 24, 24, 128)  0           ['block4d_project_bn[0][0]']
#
#  block4d_add (Add)              (None, 24, 24, 128)  0           ['block4d_drop[0][0]',
#                                                                   'block4c_add[0][0]']
#
#  block4e_expand_conv (Conv2D)   (None, 24, 24, 512)  65536       ['block4d_add[0][0]']
#
#  block4e_expand_bn (BatchNormal  (None, 24, 24, 512)  2048       ['block4e_expand_conv[0][0]']
#  ization)
#
#  block4e_expand_activation (Act  (None, 24, 24, 512)  0          ['block4e_expand_bn[0][0]']
#  ivation)
#
#  block4e_dwconv2 (DepthwiseConv  (None, 24, 24, 512)  4608       ['block4e_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4e_bn (BatchNormalization  (None, 24, 24, 512)  2048       ['block4e_dwconv2[0][0]']
#  )
#
#  block4e_activation (Activation  (None, 24, 24, 512)  0          ['block4e_bn[0][0]']
#  )
#
#  block4e_se_squeeze (GlobalAver  (None, 512)         0           ['block4e_activation[0][0]']
#  agePooling2D)
#
#  block4e_se_reshape (Reshape)   (None, 1, 1, 512)    0           ['block4e_se_squeeze[0][0]']
#
#  block4e_se_reduce (Conv2D)     (None, 1, 1, 32)     16416       ['block4e_se_reshape[0][0]']
#
#  block4e_se_expand (Conv2D)     (None, 1, 1, 512)    16896       ['block4e_se_reduce[0][0]']
#
#  block4e_se_excite (Multiply)   (None, 24, 24, 512)  0           ['block4e_activation[0][0]',
#                                                                   'block4e_se_expand[0][0]']
#
#  block4e_project_conv (Conv2D)  (None, 24, 24, 128)  65536       ['block4e_se_excite[0][0]']
#
#  block4e_project_bn (BatchNorma  (None, 24, 24, 128)  512        ['block4e_project_conv[0][0]']
#  lization)
#
#  block4e_drop (Dropout)         (None, 24, 24, 128)  0           ['block4e_project_bn[0][0]']
#
#  block4e_add (Add)              (None, 24, 24, 128)  0           ['block4e_drop[0][0]',
#                                                                   'block4d_add[0][0]']
#
#  block4f_expand_conv (Conv2D)   (None, 24, 24, 512)  65536       ['block4e_add[0][0]']
#
#  block4f_expand_bn (BatchNormal  (None, 24, 24, 512)  2048       ['block4f_expand_conv[0][0]']
#  ization)
#
#  block4f_expand_activation (Act  (None, 24, 24, 512)  0          ['block4f_expand_bn[0][0]']
#  ivation)
#
#  block4f_dwconv2 (DepthwiseConv  (None, 24, 24, 512)  4608       ['block4f_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4f_bn (BatchNormalization  (None, 24, 24, 512)  2048       ['block4f_dwconv2[0][0]']
#  )
#
#  block4f_activation (Activation  (None, 24, 24, 512)  0          ['block4f_bn[0][0]']
#  )
#
#  block4f_se_squeeze (GlobalAver  (None, 512)         0           ['block4f_activation[0][0]']
#  agePooling2D)
#
#  block4f_se_reshape (Reshape)   (None, 1, 1, 512)    0           ['block4f_se_squeeze[0][0]']
#
#  block4f_se_reduce (Conv2D)     (None, 1, 1, 32)     16416       ['block4f_se_reshape[0][0]']
#
#  block4f_se_expand (Conv2D)     (None, 1, 1, 512)    16896       ['block4f_se_reduce[0][0]']
#
#  block4f_se_excite (Multiply)   (None, 24, 24, 512)  0           ['block4f_activation[0][0]',
#                                                                   'block4f_se_expand[0][0]']
#
#  block4f_project_conv (Conv2D)  (None, 24, 24, 128)  65536       ['block4f_se_excite[0][0]']
#
#  block4f_project_bn (BatchNorma  (None, 24, 24, 128)  512        ['block4f_project_conv[0][0]']
#  lization)
#
#  block4f_drop (Dropout)         (None, 24, 24, 128)  0           ['block4f_project_bn[0][0]']
#
#  block4f_add (Add)              (None, 24, 24, 128)  0           ['block4f_drop[0][0]',
#                                                                   'block4e_add[0][0]']
#
#  block5a_expand_conv (Conv2D)   (None, 24, 24, 768)  98304       ['block4f_add[0][0]']
#
#  block5a_expand_bn (BatchNormal  (None, 24, 24, 768)  3072       ['block5a_expand_conv[0][0]']
#  ization)
#
#  block5a_expand_activation (Act  (None, 24, 24, 768)  0          ['block5a_expand_bn[0][0]']
#  ivation)
#
#  block5a_dwconv2 (DepthwiseConv  (None, 24, 24, 768)  6912       ['block5a_expand_activation[0][0]
#  2D)                                                             ']
#
#  block5a_bn (BatchNormalization  (None, 24, 24, 768)  3072       ['block5a_dwconv2[0][0]']
#  )
#
#  block5a_activation (Activation  (None, 24, 24, 768)  0          ['block5a_bn[0][0]']
#  )
#
#  block5a_se_squeeze (GlobalAver  (None, 768)         0           ['block5a_activation[0][0]']
#  agePooling2D)
#
#  block5a_se_reshape (Reshape)   (None, 1, 1, 768)    0           ['block5a_se_squeeze[0][0]']
#
#  block5a_se_reduce (Conv2D)     (None, 1, 1, 32)     24608       ['block5a_se_reshape[0][0]']
#
#  block5a_se_expand (Conv2D)     (None, 1, 1, 768)    25344       ['block5a_se_reduce[0][0]']
#
#  block5a_se_excite (Multiply)   (None, 24, 24, 768)  0           ['block5a_activation[0][0]',
#                                                                   'block5a_se_expand[0][0]']
#
#  block5a_project_conv (Conv2D)  (None, 24, 24, 160)  122880      ['block5a_se_excite[0][0]']
#
#  block5a_project_bn (BatchNorma  (None, 24, 24, 160)  640        ['block5a_project_conv[0][0]']
#  lization)
#
#  block5b_expand_conv (Conv2D)   (None, 24, 24, 960)  153600      ['block5a_project_bn[0][0]']
#
#  block5b_expand_bn (BatchNormal  (None, 24, 24, 960)  3840       ['block5b_expand_conv[0][0]']
#  ization)
#
#  block5b_expand_activation (Act  (None, 24, 24, 960)  0          ['block5b_expand_bn[0][0]']
#  ivation)
#
#  block5b_dwconv2 (DepthwiseConv  (None, 24, 24, 960)  8640       ['block5b_expand_activation[0][0]
#  2D)                                                             ']
#
#  block5b_bn (BatchNormalization  (None, 24, 24, 960)  3840       ['block5b_dwconv2[0][0]']
#  )
#
#  block5b_activation (Activation  (None, 24, 24, 960)  0          ['block5b_bn[0][0]']
#  )
#
#  block5b_se_squeeze (GlobalAver  (None, 960)         0           ['block5b_activation[0][0]']
#  agePooling2D)
#
#  block5b_se_reshape (Reshape)   (None, 1, 1, 960)    0           ['block5b_se_squeeze[0][0]']
#
#  block5b_se_reduce (Conv2D)     (None, 1, 1, 40)     38440       ['block5b_se_reshape[0][0]']
#
#  block5b_se_expand (Conv2D)     (None, 1, 1, 960)    39360       ['block5b_se_reduce[0][0]']
#
#  block5b_se_excite (Multiply)   (None, 24, 24, 960)  0           ['block5b_activation[0][0]',
#                                                                   'block5b_se_expand[0][0]']
#
#  block5b_project_conv (Conv2D)  (None, 24, 24, 160)  153600      ['block5b_se_excite[0][0]']
#
#  block5b_project_bn (BatchNorma  (None, 24, 24, 160)  640        ['block5b_project_conv[0][0]']
#  lization)
#
# ...
#  block6l_se_squeeze (GlobalAver  (None, 1536)        0           ['block6l_activation[0][0]']
#  agePooling2D)
#
#  block6l_se_reshape (Reshape)   (None, 1, 1, 1536)   0           ['block6l_se_squeeze[0][0]']
#
#  block6l_se_reduce (Conv2D)     (None, 1, 1, 64)     98368       ['block6l_se_reshape[0][0]']
#
#  block6l_se_expand (Conv2D)     (None, 1, 1, 1536)   99840       ['block6l_se_reduce[0][0]']
#
#  block6l_se_excite (Multiply)   (None, 12, 12, 1536  0           ['block6l_activation[0][0]',
#                                 )                                 'block6l_se_expand[0][0]']
#
#  block6l_project_conv (Conv2D)  (None, 12, 12, 256)  393216      ['block6l_se_excite[0][0]']
#
#  block6l_project_bn (BatchNorma  (None, 12, 12, 256)  1024       ['block6l_project_conv[0][0]']
#  lization)
#
#  block6l_drop (Dropout)         (None, 12, 12, 256)  0           ['block6l_project_bn[0][0]']
#
#  block6l_add (Add)              (None, 12, 12, 256)  0           ['block6l_drop[0][0]',
#                                                                   'block6k_add[0][0]']
#
#  block6m_expand_conv (Conv2D)   (None, 12, 12, 1536  393216      ['block6l_add[0][0]']
#                                 )
#
#  block6m_expand_bn (BatchNormal  (None, 12, 12, 1536  6144       ['block6m_expand_conv[0][0]']
#  ization)                       )
#
#  block6m_expand_activation (Act  (None, 12, 12, 1536  0          ['block6m_expand_bn[0][0]']
#  ivation)                       )
#
#  block6m_dwconv2 (DepthwiseConv  (None, 12, 12, 1536  13824      ['block6m_expand_activation[0][0]
#  2D)                            )                                ']
#
#  block6m_bn (BatchNormalization  (None, 12, 12, 1536  6144       ['block6m_dwconv2[0][0]']
#  )                              )
#
#  block6m_activation (Activation  (None, 12, 12, 1536  0          ['block6m_bn[0][0]']
#  )                              )
#
#  block6m_se_squeeze (GlobalAver  (None, 1536)        0           ['block6m_activation[0][0]']
#  agePooling2D)
#
#  block6m_se_reshape (Reshape)   (None, 1, 1, 1536)   0           ['block6m_se_squeeze[0][0]']
#
#  block6m_se_reduce (Conv2D)     (None, 1, 1, 64)     98368       ['block6m_se_reshape[0][0]']
#
#  block6m_se_expand (Conv2D)     (None, 1, 1, 1536)   99840       ['block6m_se_reduce[0][0]']
#
#  block6m_se_excite (Multiply)   (None, 12, 12, 1536  0           ['block6m_activation[0][0]',
#                                 )                                 'block6m_se_expand[0][0]']
#
#  block6m_project_conv (Conv2D)  (None, 12, 12, 256)  393216      ['block6m_se_excite[0][0]']
#
#  block6m_project_bn (BatchNorma  (None, 12, 12, 256)  1024       ['block6m_project_conv[0][0]']
#  lization)
#
#  block6m_drop (Dropout)         (None, 12, 12, 256)  0           ['block6m_project_bn[0][0]']
#
#  block6m_add (Add)              (None, 12, 12, 256)  0           ['block6m_drop[0][0]',
#                                                                   'block6l_add[0][0]']
#
#  block6n_expand_conv (Conv2D)   (None, 12, 12, 1536  393216      ['block6m_add[0][0]']
#                                 )
#
#  block6n_expand_bn (BatchNormal  (None, 12, 12, 1536  6144       ['block6n_expand_conv[0][0]']
#  ization)                       )
#
#  block6n_expand_activation (Act  (None, 12, 12, 1536  0          ['block6n_expand_bn[0][0]']
#  ivation)                       )
#
#  block6n_dwconv2 (DepthwiseConv  (None, 12, 12, 1536  13824      ['block6n_expand_activation[0][0]
#  2D)                            )                                ']
#
#  block6n_bn (BatchNormalization  (None, 12, 12, 1536  6144       ['block6n_dwconv2[0][0]']
#  )                              )
#
#  block6n_activation (Activation  (None, 12, 12, 1536  0          ['block6n_bn[0][0]']
#  )                              )
#
#  block6n_se_squeeze (GlobalAver  (None, 1536)        0           ['block6n_activation[0][0]']
#  agePooling2D)
#
#  block6n_se_reshape (Reshape)   (None, 1, 1, 1536)   0           ['block6n_se_squeeze[0][0]']
#
#  block6n_se_reduce (Conv2D)     (None, 1, 1, 64)     98368       ['block6n_se_reshape[0][0]']
#
#  block6n_se_expand (Conv2D)     (None, 1, 1, 1536)   99840       ['block6n_se_reduce[0][0]']
#
#  block6n_se_excite (Multiply)   (None, 12, 12, 1536  0           ['block6n_activation[0][0]',
#                                 )                                 'block6n_se_expand[0][0]']
#
#  block6n_project_conv (Conv2D)  (None, 12, 12, 256)  393216      ['block6n_se_excite[0][0]']
#
#  block6n_project_bn (BatchNorma  (None, 12, 12, 256)  1024       ['block6n_project_conv[0][0]']
#  lization)
#
#  block6n_drop (Dropout)         (None, 12, 12, 256)  0           ['block6n_project_bn[0][0]']
#
#  block6n_add (Add)              (None, 12, 12, 256)  0           ['block6n_drop[0][0]',
#                                                                   'block6m_add[0][0]']
#
#  block6o_expand_conv (Conv2D)   (None, 12, 12, 1536  393216      ['block6n_add[0][0]']
#                                 )
#
#  block6o_expand_bn (BatchNormal  (None, 12, 12, 1536  6144       ['block6o_expand_conv[0][0]']
#  ization)                       )
#
#  block6o_expand_activation (Act  (None, 12, 12, 1536  0          ['block6o_expand_bn[0][0]']
#  ivation)                       )
#
#  block6o_dwconv2 (DepthwiseConv  (None, 12, 12, 1536  13824      ['block6o_expand_activation[0][0]
#  2D)                            )                                ']
#
#  block6o_bn (BatchNormalization  (None, 12, 12, 1536  6144       ['block6o_dwconv2[0][0]']
#  )                              )
#
#  block6o_activation (Activation  (None, 12, 12, 1536  0          ['block6o_bn[0][0]']
#  )                              )
#
#  block6o_se_squeeze (GlobalAver  (None, 1536)        0           ['block6o_activation[0][0]']
#  agePooling2D)
#
#  block6o_se_reshape (Reshape)   (None, 1, 1, 1536)   0           ['block6o_se_squeeze[0][0]']
#
#  block6o_se_reduce (Conv2D)     (None, 1, 1, 64)     98368       ['block6o_se_reshape[0][0]']
#
#  block6o_se_expand (Conv2D)     (None, 1, 1, 1536)   99840       ['block6o_se_reduce[0][0]']
#
#  block6o_se_excite (Multiply)   (None, 12, 12, 1536  0           ['block6o_activation[0][0]',
#                                 )                                 'block6o_se_expand[0][0]']
#
#  block6o_project_conv (Conv2D)  (None, 12, 12, 256)  393216      ['block6o_se_excite[0][0]']
#
#  block6o_project_bn (BatchNorma  (None, 12, 12, 256)  1024       ['block6o_project_conv[0][0]']
#  lization)
#
#  block6o_drop (Dropout)         (None, 12, 12, 256)  0           ['block6o_project_bn[0][0]']
#
#  block6o_add (Add)              (None, 12, 12, 256)  0           ['block6o_drop[0][0]',
#                                                                   'block6n_add[0][0]']
#
#  top_conv (Conv2D)              (None, 12, 12, 1280  327680      ['block6o_add[0][0]']
#                                 )
#
#  top_bn (BatchNormalization)    (None, 12, 12, 1280  5120        ['top_conv[0][0]']
#                                 )
#
#  top_activation (Activation)    (None, 12, 12, 1280  0           ['top_bn[0][0]']
#                                 )
#
#  avg_pool (GlobalAveragePooling  (None, 1280)        0           ['top_activation[0][0]']
#  2D)
#
#  top_dropout (Dropout)          (None, 1280)         0           ['avg_pool[0][0]']
#
#  my_predictions (Dense)         (None, 2)            2562        ['top_dropout[0][0]']
#
# ==================================================================================================
# Total params: 20,333,922
# Trainable params: 2,562
# Non-trainable params: 20,331,360
# __________________________________________________________________________________________________
# None

# %%
# ModelCheckpoint callback - save best weights
estopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=20)
checkpoint = ModelCheckpoint(filepath='/content/drive/MyDrive/Mestrado/Experimentos/exp-retina/exp-retina-pynb/model_efficientnetv2s.weights.best.hdf5', save_best_only=True, verbose=0)
history = EfficientNetV2S_model.fit(x_train1, y_train, epochs=200, batch_size=16, verbose=1, shuffle=True, validation_split=0.1, callbacks=[checkpoint, estopping])
# Out:
# Epoch 1/200
# 17/17 [==============================] - 21s 629ms/step - loss: 0.8737 - accuracy: 0.3296 - val_loss: 0.7012 - val_accuracy: 0.5333
# Epoch 2/200
# 17/17 [==============================] - 7s 436ms/step - loss: 0.6920 - accuracy: 0.5963 - val_loss: 0.6671 - val_accuracy: 0.6000
# Epoch 3/200
# 17/17 [==============================] - 3s 201ms/step - loss: 0.5683 - accuracy: 0.7333 - val_loss: 0.6812 - val_accuracy: 0.6000
# Epoch 4/200
# 17/17 [==============================] - 3s 200ms/step - loss: 0.5184 - accuracy: 0.7630 - val_loss: 0.6814 - val_accuracy: 0.6000
# Epoch 5/200
# 17/17 [==============================] - 3s 201ms/step - loss: 0.5213 - accuracy: 0.7519 - val_loss: 0.6788 - val_accuracy: 0.6000
# Epoch 6/200
# 17/17 [==============================] - 7s 433ms/step - loss: 0.4907 - accuracy: 0.7593 - val_loss: 0.6609 - val_accuracy: 0.6000
# Epoch 7/200
# 17/17 [==============================] - 7s 415ms/step - loss: 0.4976 - accuracy: 0.7704 - val_loss: 0.6407 - val_accuracy: 0.6000
# Epoch 8/200
# 17/17 [==============================] - 7s 431ms/step - loss: 0.4515 - accuracy: 0.7815 - val_loss: 0.6290 - val_accuracy: 0.6000
# Epoch 9/200
# 17/17 [==============================] - 7s 438ms/step - loss: 0.4523 - accuracy: 0.7852 - val_loss: 0.6051 - val_accuracy: 0.6000
# Epoch 10/200
# 17/17 [==============================] - 7s 421ms/step - loss: 0.4454 - accuracy: 0.8000 - val_loss: 0.5939 - val_accuracy: 0.6333
# Epoch 11/200
# 17/17 [==============================] - 7s 426ms/step - loss: 0.4323 - accuracy: 0.7963 - val_loss: 0.5802 - val_accuracy: 0.6333
# Epoch 12/200
# 17/17 [==============================] - 7s 416ms/step - loss: 0.4215 - accuracy: 0.8074 - val_loss: 0.5644 - val_accuracy: 0.6667
# Epoch 13/200
# 17/17 [==============================] - 7s 405ms/step - loss: 0.4222 - accuracy: 0.8074 - val_loss: 0.5534 - val_accuracy: 0.6667
# Epoch 14/200
# 17/17 [==============================] - 7s 422ms/step - loss: 0.4036 - accuracy: 0.8185 - val_loss: 0.5465 - val_accuracy: 0.6667
# Epoch 15/200
# 17/17 [==============================] - 7s 430ms/step - loss: 0.4020 - accuracy: 0.8259 - val_loss: 0.5339 - val_accuracy: 0.6667
# Epoch 16/200
# 17/17 [==============================] - 7s 433ms/step - loss: 0.3798 - accuracy: 0.8407 - val_loss: 0.5306 - val_accuracy: 0.6667
# Epoch 17/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.3839 - accuracy: 0.8296 - val_loss: 0.5201 - val_accuracy: 0.7000
# Epoch 18/200
# 17/17 [==============================] - 7s 424ms/step - loss: 0.3720 - accuracy: 0.8407 - val_loss: 0.5055 - val_accuracy: 0.7000
# Epoch 19/200
# 17/17 [==============================] - 7s 424ms/step - loss: 0.3756 - accuracy: 0.8444 - val_loss: 0.5020 - val_accuracy: 0.7333
# Epoch 20/200
# 17/17 [==============================] - 7s 445ms/step - loss: 0.3586 - accuracy: 0.8556 - val_loss: 0.4989 - val_accuracy: 0.7333
# Epoch 21/200
# 17/17 [==============================] - 7s 433ms/step - loss: 0.3458 - accuracy: 0.8519 - val_loss: 0.4818 - val_accuracy: 0.7333
# Epoch 22/200
# 17/17 [==============================] - 7s 441ms/step - loss: 0.3441 - accuracy: 0.8704 - val_loss: 0.4777 - val_accuracy: 0.7333
# Epoch 23/200
# 17/17 [==============================] - 7s 415ms/step - loss: 0.3331 - accuracy: 0.8630 - val_loss: 0.4739 - val_accuracy: 0.7333
# Epoch 24/200
# 17/17 [==============================] - 7s 415ms/step - loss: 0.3187 - accuracy: 0.8556 - val_loss: 0.4645 - val_accuracy: 0.7333
# Epoch 25/200
# 17/17 [==============================] - 7s 417ms/step - loss: 0.3282 - accuracy: 0.8593 - val_loss: 0.4599 - val_accuracy: 0.7667
# Epoch 26/200
# 17/17 [==============================] - 3s 198ms/step - loss: 0.3409 - accuracy: 0.8593 - val_loss: 0.4640 - val_accuracy: 0.7333
# Epoch 27/200
# 17/17 [==============================] - 7s 433ms/step - loss: 0.3134 - accuracy: 0.8593 - val_loss: 0.4529 - val_accuracy: 0.8000
# Epoch 28/200
# 17/17 [==============================] - 3s 199ms/step - loss: 0.3157 - accuracy: 0.8741 - val_loss: 0.4537 - val_accuracy: 0.8000
# Epoch 29/200
# 17/17 [==============================] - 7s 425ms/step - loss: 0.3119 - accuracy: 0.8667 - val_loss: 0.4434 - val_accuracy: 0.8000
# Epoch 30/200
# 17/17 [==============================] - 8s 461ms/step - loss: 0.3068 - accuracy: 0.8778 - val_loss: 0.4430 - val_accuracy: 0.8000
# Epoch 31/200
# 17/17 [==============================] - 3s 198ms/step - loss: 0.3077 - accuracy: 0.8778 - val_loss: 0.4444 - val_accuracy: 0.8000
# Epoch 32/200
# 17/17 [==============================] - 7s 432ms/step - loss: 0.2906 - accuracy: 0.8667 - val_loss: 0.4385 - val_accuracy: 0.8000
# Epoch 33/200
# 17/17 [==============================] - 7s 432ms/step - loss: 0.3023 - accuracy: 0.8741 - val_loss: 0.4378 - val_accuracy: 0.8000
# Epoch 34/200
# 17/17 [==============================] - 7s 436ms/step - loss: 0.3048 - accuracy: 0.8704 - val_loss: 0.4371 - val_accuracy: 0.8000
# Epoch 35/200
# 17/17 [==============================] - 7s 425ms/step - loss: 0.2960 - accuracy: 0.8926 - val_loss: 0.4322 - val_accuracy: 0.8000
# Epoch 36/200
# 17/17 [==============================] - 7s 433ms/step - loss: 0.2970 - accuracy: 0.8778 - val_loss: 0.4294 - val_accuracy: 0.8000
# Epoch 37/200
# 17/17 [==============================] - 7s 428ms/step - loss: 0.3014 - accuracy: 0.8741 - val_loss: 0.4199 - val_accuracy: 0.8000
# Epoch 38/200
# 17/17 [==============================] - 3s 199ms/step - loss: 0.2807 - accuracy: 0.8815 - val_loss: 0.4217 - val_accuracy: 0.8000
# Epoch 39/200
# 17/17 [==============================] - 7s 425ms/step - loss: 0.2741 - accuracy: 0.8852 - val_loss: 0.4158 - val_accuracy: 0.8333
# Epoch 40/200
# 17/17 [==============================] - 3s 200ms/step - loss: 0.2876 - accuracy: 0.9000 - val_loss: 0.4158 - val_accuracy: 0.8333
# Epoch 41/200
# 17/17 [==============================] - 3s 199ms/step - loss: 0.2849 - accuracy: 0.8889 - val_loss: 0.4211 - val_accuracy: 0.8000
# Epoch 42/200
# 17/17 [==============================] - 3s 200ms/step - loss: 0.2844 - accuracy: 0.8889 - val_loss: 0.4178 - val_accuracy: 0.8000
# Epoch 43/200
# 17/17 [==============================] - 8s 468ms/step - loss: 0.2973 - accuracy: 0.8815 - val_loss: 0.4093 - val_accuracy: 0.8333
# Epoch 44/200
# 17/17 [==============================] - 3s 198ms/step - loss: 0.2667 - accuracy: 0.8926 - val_loss: 0.4099 - val_accuracy: 0.8333
# Epoch 45/200
# 17/17 [==============================] - 3s 197ms/step - loss: 0.2618 - accuracy: 0.9185 - val_loss: 0.4140 - val_accuracy: 0.8333
# Epoch 46/200
# 17/17 [==============================] - 3s 199ms/step - loss: 0.2656 - accuracy: 0.8926 - val_loss: 0.4163 - val_accuracy: 0.8000
# Epoch 47/200
# 17/17 [==============================] - 7s 420ms/step - loss: 0.2547 - accuracy: 0.9111 - val_loss: 0.4084 - val_accuracy: 0.8333
# Epoch 48/200
# 17/17 [==============================] - 3s 198ms/step - loss: 0.2629 - accuracy: 0.8963 - val_loss: 0.4139 - val_accuracy: 0.8333
# Epoch 49/200
# 17/17 [==============================] - 3s 197ms/step - loss: 0.2567 - accuracy: 0.9000 - val_loss: 0.4163 - val_accuracy: 0.8000
# Epoch 50/200
# 17/17 [==============================] - 7s 436ms/step - loss: 0.2543 - accuracy: 0.8926 - val_loss: 0.4051 - val_accuracy: 0.8333
# Epoch 51/200
# 17/17 [==============================] - 3s 197ms/step - loss: 0.2530 - accuracy: 0.9111 - val_loss: 0.4117 - val_accuracy: 0.8333
# Epoch 52/200
# 17/17 [==============================] - 3s 199ms/step - loss: 0.2668 - accuracy: 0.8852 - val_loss: 0.4062 - val_accuracy: 0.8333
# Epoch 53/200
# 17/17 [==============================] - 7s 446ms/step - loss: 0.2501 - accuracy: 0.9074 - val_loss: 0.4050 - val_accuracy: 0.8333
# Epoch 54/200
# 17/17 [==============================] - 3s 198ms/step - loss: 0.2392 - accuracy: 0.9074 - val_loss: 0.4062 - val_accuracy: 0.8333
# Epoch 55/200
# 17/17 [==============================] - 7s 441ms/step - loss: 0.2389 - accuracy: 0.8963 - val_loss: 0.4007 - val_accuracy: 0.8333
# Epoch 56/200
# 17/17 [==============================] - 8s 462ms/step - loss: 0.2438 - accuracy: 0.8963 - val_loss: 0.4000 - val_accuracy: 0.8333
# Epoch 57/200
# 17/17 [==============================] - 7s 426ms/step - loss: 0.2574 - accuracy: 0.9074 - val_loss: 0.3993 - val_accuracy: 0.8333
# Epoch 58/200
# 17/17 [==============================] - 7s 418ms/step - loss: 0.2416 - accuracy: 0.9111 - val_loss: 0.3959 - val_accuracy: 0.8333
# Epoch 59/200
# 17/17 [==============================] - 3s 198ms/step - loss: 0.2519 - accuracy: 0.9000 - val_loss: 0.3980 - val_accuracy: 0.8333
# Epoch 60/200
# 17/17 [==============================] - 3s 200ms/step - loss: 0.2418 - accuracy: 0.9074 - val_loss: 0.3976 - val_accuracy: 0.8333
# Epoch 61/200
# 17/17 [==============================] - 7s 426ms/step - loss: 0.2479 - accuracy: 0.9111 - val_loss: 0.3948 - val_accuracy: 0.8333
# Epoch 62/200
# 17/17 [==============================] - 3s 198ms/step - loss: 0.2538 - accuracy: 0.8926 - val_loss: 0.3963 - val_accuracy: 0.8333
# Epoch 63/200
# 17/17 [==============================] - 3s 201ms/step - loss: 0.2435 - accuracy: 0.9148 - val_loss: 0.3952 - val_accuracy: 0.8333
# Epoch 64/200
# 17/17 [==============================] - 7s 423ms/step - loss: 0.2442 - accuracy: 0.8963 - val_loss: 0.3944 - val_accuracy: 0.8333
# Epoch 65/200
# 17/17 [==============================] - 3s 200ms/step - loss: 0.2324 - accuracy: 0.9074 - val_loss: 0.4001 - val_accuracy: 0.8333
# Epoch 66/200
# 17/17 [==============================] - 3s 200ms/step - loss: 0.2461 - accuracy: 0.9148 - val_loss: 0.3983 - val_accuracy: 0.8333
# Epoch 67/200
# 17/17 [==============================] - 3s 200ms/step - loss: 0.2201 - accuracy: 0.9222 - val_loss: 0.3969 - val_accuracy: 0.8333
# Epoch 68/200
# 17/17 [==============================] - 8s 465ms/step - loss: 0.2238 - accuracy: 0.9037 - val_loss: 0.3940 - val_accuracy: 0.8333
# Epoch 69/200
# 17/17 [==============================] - 3s 198ms/step - loss: 0.2326 - accuracy: 0.9148 - val_loss: 0.3946 - val_accuracy: 0.8333
# Epoch 70/200
# 17/17 [==============================] - 3s 198ms/step - loss: 0.2276 - accuracy: 0.9259 - val_loss: 0.3958 - val_accuracy: 0.8333
# Epoch 71/200
# 17/17 [==============================] - 7s 447ms/step - loss: 0.2398 - accuracy: 0.9111 - val_loss: 0.3909 - val_accuracy: 0.8333
# Epoch 72/200
# 17/17 [==============================] - 7s 416ms/step - loss: 0.2314 - accuracy: 0.9000 - val_loss: 0.3805 - val_accuracy: 0.8333
# Epoch 73/200
# 17/17 [==============================] - 3s 197ms/step - loss: 0.2272 - accuracy: 0.9037 - val_loss: 0.3810 - val_accuracy: 0.8333
# Epoch 74/200
# 17/17 [==============================] - 3s 197ms/step - loss: 0.2313 - accuracy: 0.9148 - val_loss: 0.3913 - val_accuracy: 0.8333
# Epoch 75/200
# 17/17 [==============================] - 3s 197ms/step - loss: 0.2426 - accuracy: 0.8963 - val_loss: 0.3924 - val_accuracy: 0.8333
# Epoch 76/200
# 17/17 [==============================] - 3s 198ms/step - loss: 0.2336 - accuracy: 0.9185 - val_loss: 0.3830 - val_accuracy: 0.8333
# Epoch 77/200
# 17/17 [==============================] - 3s 199ms/step - loss: 0.2257 - accuracy: 0.9074 - val_loss: 0.3830 - val_accuracy: 0.8333
# Epoch 78/200
# 17/17 [==============================] - 7s 439ms/step - loss: 0.2234 - accuracy: 0.9222 - val_loss: 0.3783 - val_accuracy: 0.8333
# Epoch 79/200
# 17/17 [==============================] - 3s 199ms/step - loss: 0.2227 - accuracy: 0.9037 - val_loss: 0.3949 - val_accuracy: 0.8333
# Epoch 80/200
# 17/17 [==============================] - 3s 199ms/step - loss: 0.2218 - accuracy: 0.9037 - val_loss: 0.3830 - val_accuracy: 0.8333
# Epoch 81/200
# 17/17 [==============================] - 3s 198ms/step - loss: 0.2321 - accuracy: 0.9148 - val_loss: 0.3831 - val_accuracy: 0.8333
# Epoch 82/200
# 17/17 [==============================] - 3s 198ms/step - loss: 0.2398 - accuracy: 0.9111 - val_loss: 0.3814 - val_accuracy: 0.8333
# Epoch 83/200
# 17/17 [==============================] - 3s 198ms/step - loss: 0.2356 - accuracy: 0.9111 - val_loss: 0.3802 - val_accuracy: 0.8333
# Epoch 84/200
# 17/17 [==============================] - 7s 454ms/step - loss: 0.2202 - accuracy: 0.9148 - val_loss: 0.3764 - val_accuracy: 0.8333
# Epoch 85/200
# 17/17 [==============================] - 3s 196ms/step - loss: 0.2219 - accuracy: 0.9148 - val_loss: 0.3798 - val_accuracy: 0.8333
# Epoch 86/200
# 17/17 [==============================] - 7s 420ms/step - loss: 0.2133 - accuracy: 0.9148 - val_loss: 0.3759 - val_accuracy: 0.8333
# Epoch 87/200
# 17/17 [==============================] - 3s 197ms/step - loss: 0.2222 - accuracy: 0.9222 - val_loss: 0.3831 - val_accuracy: 0.8333
# Epoch 88/200
# 17/17 [==============================] - 3s 197ms/step - loss: 0.2146 - accuracy: 0.9185 - val_loss: 0.3801 - val_accuracy: 0.8333
# Epoch 89/200
# 17/17 [==============================] - 3s 199ms/step - loss: 0.2190 - accuracy: 0.9111 - val_loss: 0.3881 - val_accuracy: 0.8333
# Epoch 90/200
# 17/17 [==============================] - 3s 198ms/step - loss: 0.2295 - accuracy: 0.9074 - val_loss: 0.3834 - val_accuracy: 0.8333
# Epoch 91/200
# 17/17 [==============================] - 3s 199ms/step - loss: 0.2249 - accuracy: 0.9111 - val_loss: 0.3825 - val_accuracy: 0.8333
# Epoch 92/200
# 17/17 [==============================] - 3s 200ms/step - loss: 0.2259 - accuracy: 0.9037 - val_loss: 0.3762 - val_accuracy: 0.8333
# Epoch 93/200
# 17/17 [==============================] - 3s 200ms/step - loss: 0.2131 - accuracy: 0.9259 - val_loss: 0.3797 - val_accuracy: 0.8333
# Epoch 94/200
# 17/17 [==============================] - 7s 427ms/step - loss: 0.2279 - accuracy: 0.9000 - val_loss: 0.3696 - val_accuracy: 0.8333
# Epoch 95/200
# 17/17 [==============================] - 3s 198ms/step - loss: 0.2063 - accuracy: 0.9407 - val_loss: 0.3750 - val_accuracy: 0.8333
# Epoch 96/200
# 17/17 [==============================] - 3s 198ms/step - loss: 0.2203 - accuracy: 0.9296 - val_loss: 0.3739 - val_accuracy: 0.8333
# Epoch 97/200
# 17/17 [==============================] - 3s 199ms/step - loss: 0.2199 - accuracy: 0.9148 - val_loss: 0.3766 - val_accuracy: 0.8333
# Epoch 98/200
# 17/17 [==============================] - 3s 198ms/step - loss: 0.2138 - accuracy: 0.9296 - val_loss: 0.3838 - val_accuracy: 0.8333
# Epoch 99/200
# 17/17 [==============================] - 3s 200ms/step - loss: 0.2090 - accuracy: 0.9185 - val_loss: 0.3778 - val_accuracy: 0.8333
# Epoch 100/200
# 17/17 [==============================] - 3s 199ms/step - loss: 0.2146 - accuracy: 0.9148 - val_loss: 0.3717 - val_accuracy: 0.8333
# Epoch 101/200
# 17/17 [==============================] - 3s 200ms/step - loss: 0.2009 - accuracy: 0.9333 - val_loss: 0.3778 - val_accuracy: 0.8333
# Epoch 102/200
# 17/17 [==============================] - 3s 199ms/step - loss: 0.2223 - accuracy: 0.9185 - val_loss: 0.3752 - val_accuracy: 0.8333
# Epoch 103/200
# 17/17 [==============================] - 3s 198ms/step - loss: 0.1951 - accuracy: 0.9296 - val_loss: 0.3719 - val_accuracy: 0.8333
# Epoch 104/200
# 17/17 [==============================] - 3s 199ms/step - loss: 0.2185 - accuracy: 0.9037 - val_loss: 0.3815 - val_accuracy: 0.8333
# Epoch 105/200
# 17/17 [==============================] - 3s 198ms/step - loss: 0.2119 - accuracy: 0.9259 - val_loss: 0.3699 - val_accuracy: 0.8333
# Epoch 106/200
# 17/17 [==============================] - 3s 199ms/step - loss: 0.1987 - accuracy: 0.9148 - val_loss: 0.3818 - val_accuracy: 0.8333
# Epoch 107/200
# 17/17 [==============================] - 3s 199ms/step - loss: 0.2099 - accuracy: 0.9111 - val_loss: 0.3746 - val_accuracy: 0.8333
# Epoch 108/200
# 17/17 [==============================] - 3s 198ms/step - loss: 0.2073 - accuracy: 0.9333 - val_loss: 0.3755 - val_accuracy: 0.8333
# Epoch 109/200
# 17/17 [==============================] - 3s 198ms/step - loss: 0.1995 - accuracy: 0.9259 - val_loss: 0.3736 - val_accuracy: 0.8333
# Epoch 110/200
# 17/17 [==============================] - 3s 198ms/step - loss: 0.2133 - accuracy: 0.9074 - val_loss: 0.3776 - val_accuracy: 0.8333
# Epoch 111/200
# 17/17 [==============================] - 7s 452ms/step - loss: 0.2026 - accuracy: 0.9333 - val_loss: 0.3655 - val_accuracy: 0.8333
# Epoch 112/200
# 17/17 [==============================] - 3s 196ms/step - loss: 0.2131 - accuracy: 0.9037 - val_loss: 0.3734 - val_accuracy: 0.8333
# Epoch 113/200
# 17/17 [==============================] - 3s 198ms/step - loss: 0.2081 - accuracy: 0.9222 - val_loss: 0.3739 - val_accuracy: 0.8333
# Epoch 114/200
# 17/17 [==============================] - 3s 197ms/step - loss: 0.2171 - accuracy: 0.9296 - val_loss: 0.3864 - val_accuracy: 0.8333
# Epoch 115/200
# 17/17 [==============================] - 3s 198ms/step - loss: 0.2247 - accuracy: 0.9259 - val_loss: 0.3751 - val_accuracy: 0.8333
# Epoch 116/200
# 17/17 [==============================] - 3s 199ms/step - loss: 0.1902 - accuracy: 0.9407 - val_loss: 0.3679 - val_accuracy: 0.8333
# Epoch 117/200
# 17/17 [==============================] - 3s 199ms/step - loss: 0.2167 - accuracy: 0.9074 - val_loss: 0.3666 - val_accuracy: 0.8333
# Epoch 118/200
# 17/17 [==============================] - 3s 199ms/step - loss: 0.1970 - accuracy: 0.9259 - val_loss: 0.3725 - val_accuracy: 0.8333
# Epoch 119/200
# 17/17 [==============================] - 3s 199ms/step - loss: 0.1805 - accuracy: 0.9407 - val_loss: 0.3834 - val_accuracy: 0.8333
# Epoch 120/200
# 17/17 [==============================] - 3s 199ms/step - loss: 0.2003 - accuracy: 0.9370 - val_loss: 0.3785 - val_accuracy: 0.8333
# Epoch 121/200
# 17/17 [==============================] - 3s 198ms/step - loss: 0.1900 - accuracy: 0.9259 - val_loss: 0.3784 - val_accuracy: 0.8333
# Epoch 122/200
# 17/17 [==============================] - 3s 199ms/step - loss: 0.2130 - accuracy: 0.9148 - val_loss: 0.3818 - val_accuracy: 0.8333
# Epoch 123/200
# 17/17 [==============================] - 3s 199ms/step - loss: 0.1886 - accuracy: 0.9407 - val_loss: 0.3733 - val_accuracy: 0.8333
# Epoch 124/200
# 17/17 [==============================] - 3s 199ms/step - loss: 0.1975 - accuracy: 0.9222 - val_loss: 0.3775 - val_accuracy: 0.8333
# Epoch 125/200
# 17/17 [==============================] - 3s 197ms/step - loss: 0.2051 - accuracy: 0.9259 - val_loss: 0.3788 - val_accuracy: 0.8333
# Epoch 126/200
# 17/17 [==============================] - 3s 199ms/step - loss: 0.2012 - accuracy: 0.9185 - val_loss: 0.3697 - val_accuracy: 0.8333
# Epoch 127/200
# 17/17 [==============================] - 3s 200ms/step - loss: 0.2205 - accuracy: 0.9037 - val_loss: 0.3728 - val_accuracy: 0.8333
# Epoch 128/200
# 17/17 [==============================] - 3s 198ms/step - loss: 0.1924 - accuracy: 0.9370 - val_loss: 0.3800 - val_accuracy: 0.8333
# Epoch 129/200
# 17/17 [==============================] - 3s 198ms/step - loss: 0.2124 - accuracy: 0.9222 - val_loss: 0.3811 - val_accuracy: 0.8333
# Epoch 130/200
# 17/17 [==============================] - 3s 199ms/step - loss: 0.1977 - accuracy: 0.9185 - val_loss: 0.3688 - val_accuracy: 0.8333
# Epoch 131/200
# 17/17 [==============================] - 3s 199ms/step - loss: 0.2098 - accuracy: 0.9333 - val_loss: 0.3796 - val_accuracy: 0.8333

# %%
plt.figure(figsize=(12,4))
plt.subplot(121), plt.plot(history.history['loss'], label='loss')
plt.subplot(121), plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Época', fontsize=12), plt.ylabel('Loss', fontsize=12)
plt.title('Evolução da curva de perda')
plt.legend()
plt.subplot(122), plt.plot(history.history['accuracy'], label = 'accuracy', color='green')
plt.subplot(122), plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Época', fontsize=12), plt.ylabel('Acc', fontsize=12)
plt.title('Evolução da curva de acurácia')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
### TEST ACC ###
scores = EfficientNetV2S_model.evaluate(x_test1, y_test)
print('\n%s : %.2f%%' % (EfficientNetV2S_model.metrics_names[1], scores[1] * 100))
# Out:
# 4/4 [==============================] - 1s 230ms/step - loss: 0.2280 - accuracy: 0.9300
#
# accuracy : 93.00%

# %% [markdown]
# #### Random Initialization

# %%
# prepare the image for the EfficientNetV2S model
x_train1 = preprocess_input(x_train)
x_test1 = preprocess_input(x_test)

# %%
def non_pre_trained_model(input_shape, n_classes, optimizer, fine_tune=0):
    """
    input_shape: tuple - the shape of input images (width, height, channels)
    n_classes: int - number of classes for the output layer
    optimizer: string - instantiated optimizer to use for training.
    fine_tune: int - The number of pre-trained layers to unfreeze. 
               0 = all pretrained layers will freeze during training
    """
    
    # Pretrained convolutional layers are loaded using the Imagenet weights.
    # Include_top is set to False, in order to exclude the model's fully-connected layers.
    efficientnetv2s_model = EfficientNetV2S(include_top=True,
                     weights=None, 
                     input_shape=input_shape)
    
    # Defines how many layers to freeze during training.
    # Layers in the convolutional base are switched from trainable to non-trainable
    # depending on the size of the fine-tuning parameter.
    '''
    if fine_tune > 0:
        for layer in efficientnetv2s_model.layers[:-fine_tune]:
            layer.trainable = False
    else:
        for layer in efficientnetv2s_model.layers:
            layer.trainable = False
    '''
    
    # Turn all the layers trainable.

    for layer in efficientnetv2s_model.layers:
      layer.trainable = True

    # Create a new 'top' of the model (i.e. fully-connected layers).
    # This is 'bootstrapping' a new top_model onto the pretrained layers.
    top_model = efficientnetv2s_model.layers[-2].output
    #top_model = Flatten(name="flatten")(top_model)
    #top_model = Dense(4096, activation='relu')(top_model)
    #top_model = Dense(128, activation='relu')(top_model)
    #top_model = Dropout(0.25)(top_model)
    output_layer = Dense(n_classes, activation='softmax', name='my_predictions')(top_model)
    
    # Group the convolutional base and new output into a Model object.
    model = Model(inputs=efficientnetv2s_model.input, outputs=output_layer)

    # Compiles the model for training.
    model.compile(optimizer=optimizer, 
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    
    return model

# %%
tf.random.set_seed(s) #s
opt = Adam(learning_rate=0.0001)
EfficientNetV2S_model = non_pre_trained_model(input_shape=(384,384,3), n_classes=2, optimizer=opt)

# %%
print(EfficientNetV2S_model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 384, 384, 3  0           []
#                                 )]
#
#  rescaling (Rescaling)          (None, 384, 384, 3)  0           ['input_1[0][0]']
#
#  stem_conv (Conv2D)             (None, 192, 192, 24  648         ['rescaling[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 192, 192, 24  96          ['stem_conv[0][0]']
#                                 )
#
#  stem_activation (Activation)   (None, 192, 192, 24  0           ['stem_bn[0][0]']
#                                 )
#
#  block1a_project_conv (Conv2D)  (None, 192, 192, 24  5184        ['stem_activation[0][0]']
#                                 )
#
#  block1a_project_bn (BatchNorma  (None, 192, 192, 24  96         ['block1a_project_conv[0][0]']
#  lization)                      )
#
#  block1a_project_activation (Ac  (None, 192, 192, 24  0          ['block1a_project_bn[0][0]']
#  tivation)                      )
#
#  block1a_add (Add)              (None, 192, 192, 24  0           ['block1a_project_activation[0][0
#                                 )                                ]',
#                                                                   'stem_activation[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, 192, 192, 24  5184        ['block1a_add[0][0]']
#                                 )
#
#  block1b_project_bn (BatchNorma  (None, 192, 192, 24  96         ['block1b_project_conv[0][0]']
#  lization)                      )
#
#  block1b_project_activation (Ac  (None, 192, 192, 24  0          ['block1b_project_bn[0][0]']
#  tivation)                      )
#
#  block1b_drop (Dropout)         (None, 192, 192, 24  0           ['block1b_project_activation[0][0
#                                 )                                ]']
#
#  block1b_add (Add)              (None, 192, 192, 24  0           ['block1b_drop[0][0]',
#                                 )                                 'block1a_add[0][0]']
#
#  block2a_expand_conv (Conv2D)   (None, 96, 96, 96)   20736       ['block1b_add[0][0]']
#
#  block2a_expand_bn (BatchNormal  (None, 96, 96, 96)  384         ['block2a_expand_conv[0][0]']
#  ization)
#
#  block2a_expand_activation (Act  (None, 96, 96, 96)  0           ['block2a_expand_bn[0][0]']
#  ivation)
#
#  block2a_project_conv (Conv2D)  (None, 96, 96, 48)   4608        ['block2a_expand_activation[0][0]
#                                                                  ']
#
#  block2a_project_bn (BatchNorma  (None, 96, 96, 48)  192         ['block2a_project_conv[0][0]']
#  lization)
#
#  block2b_expand_conv (Conv2D)   (None, 96, 96, 192)  82944       ['block2a_project_bn[0][0]']
#
#  block2b_expand_bn (BatchNormal  (None, 96, 96, 192)  768        ['block2b_expand_conv[0][0]']
#  ization)
#
#  block2b_expand_activation (Act  (None, 96, 96, 192)  0          ['block2b_expand_bn[0][0]']
#  ivation)
#
#  block2b_project_conv (Conv2D)  (None, 96, 96, 48)   9216        ['block2b_expand_activation[0][0]
#                                                                  ']
#
#  block2b_project_bn (BatchNorma  (None, 96, 96, 48)  192         ['block2b_project_conv[0][0]']
#  lization)
#
#  block2b_drop (Dropout)         (None, 96, 96, 48)   0           ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)              (None, 96, 96, 48)   0           ['block2b_drop[0][0]',
#                                                                   'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, 96, 96, 192)  82944       ['block2b_add[0][0]']
#
#  block2c_expand_bn (BatchNormal  (None, 96, 96, 192)  768        ['block2c_expand_conv[0][0]']
#  ization)
#
#  block2c_expand_activation (Act  (None, 96, 96, 192)  0          ['block2c_expand_bn[0][0]']
#  ivation)
#
#  block2c_project_conv (Conv2D)  (None, 96, 96, 48)   9216        ['block2c_expand_activation[0][0]
#                                                                  ']
#
#  block2c_project_bn (BatchNorma  (None, 96, 96, 48)  192         ['block2c_project_conv[0][0]']
#  lization)
#
#  block2c_drop (Dropout)         (None, 96, 96, 48)   0           ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)              (None, 96, 96, 48)   0           ['block2c_drop[0][0]',
#                                                                   'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2D)   (None, 96, 96, 192)  82944       ['block2c_add[0][0]']
#
#  block2d_expand_bn (BatchNormal  (None, 96, 96, 192)  768        ['block2d_expand_conv[0][0]']
#  ization)
#
#  block2d_expand_activation (Act  (None, 96, 96, 192)  0          ['block2d_expand_bn[0][0]']
#  ivation)
#
#  block2d_project_conv (Conv2D)  (None, 96, 96, 48)   9216        ['block2d_expand_activation[0][0]
#                                                                  ']
#
#  block2d_project_bn (BatchNorma  (None, 96, 96, 48)  192         ['block2d_project_conv[0][0]']
#  lization)
#
#  block2d_drop (Dropout)         (None, 96, 96, 48)   0           ['block2d_project_bn[0][0]']
#
#  block2d_add (Add)              (None, 96, 96, 48)   0           ['block2d_drop[0][0]',
#                                                                   'block2c_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 48, 48, 192)  82944       ['block2d_add[0][0]']
#
#  block3a_expand_bn (BatchNormal  (None, 48, 48, 192)  768        ['block3a_expand_conv[0][0]']
#  ization)
#
#  block3a_expand_activation (Act  (None, 48, 48, 192)  0          ['block3a_expand_bn[0][0]']
#  ivation)
#
#  block3a_project_conv (Conv2D)  (None, 48, 48, 64)   12288       ['block3a_expand_activation[0][0]
#                                                                  ']
#
#  block3a_project_bn (BatchNorma  (None, 48, 48, 64)  256         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 48, 48, 256)  147456      ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 48, 48, 256)  1024       ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 48, 48, 256)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_project_conv (Conv2D)  (None, 48, 48, 64)   16384       ['block3b_expand_activation[0][0]
#                                                                  ']
#
#  block3b_project_bn (BatchNorma  (None, 48, 48, 64)  256         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (Dropout)         (None, 48, 48, 64)   0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 48, 48, 64)   0           ['block3b_drop[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2D)   (None, 48, 48, 256)  147456      ['block3b_add[0][0]']
#
#  block3c_expand_bn (BatchNormal  (None, 48, 48, 256)  1024       ['block3c_expand_conv[0][0]']
#  ization)
#
#  block3c_expand_activation (Act  (None, 48, 48, 256)  0          ['block3c_expand_bn[0][0]']
#  ivation)
#
#  block3c_project_conv (Conv2D)  (None, 48, 48, 64)   16384       ['block3c_expand_activation[0][0]
#                                                                  ']
#
#  block3c_project_bn (BatchNorma  (None, 48, 48, 64)  256         ['block3c_project_conv[0][0]']
#  lization)
#
#  block3c_drop (Dropout)         (None, 48, 48, 64)   0           ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)              (None, 48, 48, 64)   0           ['block3c_drop[0][0]',
#                                                                   'block3b_add[0][0]']
#
#  block3d_expand_conv (Conv2D)   (None, 48, 48, 256)  147456      ['block3c_add[0][0]']
#
#  block3d_expand_bn (BatchNormal  (None, 48, 48, 256)  1024       ['block3d_expand_conv[0][0]']
#  ization)
#
#  block3d_expand_activation (Act  (None, 48, 48, 256)  0          ['block3d_expand_bn[0][0]']
#  ivation)
#
#  block3d_project_conv (Conv2D)  (None, 48, 48, 64)   16384       ['block3d_expand_activation[0][0]
#                                                                  ']
#
#  block3d_project_bn (BatchNorma  (None, 48, 48, 64)  256         ['block3d_project_conv[0][0]']
#  lization)
#
#  block3d_drop (Dropout)         (None, 48, 48, 64)   0           ['block3d_project_bn[0][0]']
#
#  block3d_add (Add)              (None, 48, 48, 64)   0           ['block3d_drop[0][0]',
#                                                                   'block3c_add[0][0]']
#
#  block4a_expand_conv (Conv2D)   (None, 48, 48, 256)  16384       ['block3d_add[0][0]']
#
#  block4a_expand_bn (BatchNormal  (None, 48, 48, 256)  1024       ['block4a_expand_conv[0][0]']
#  ization)
#
#  block4a_expand_activation (Act  (None, 48, 48, 256)  0          ['block4a_expand_bn[0][0]']
#  ivation)
#
#  block4a_dwconv2 (DepthwiseConv  (None, 24, 24, 256)  2304       ['block4a_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4a_bn (BatchNormalization  (None, 24, 24, 256)  1024       ['block4a_dwconv2[0][0]']
#  )
#
#  block4a_activation (Activation  (None, 24, 24, 256)  0          ['block4a_bn[0][0]']
#  )
#
#  block4a_se_squeeze (GlobalAver  (None, 256)         0           ['block4a_activation[0][0]']
#  agePooling2D)
#
#  block4a_se_reshape (Reshape)   (None, 1, 1, 256)    0           ['block4a_se_squeeze[0][0]']
#
#  block4a_se_reduce (Conv2D)     (None, 1, 1, 16)     4112        ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)     (None, 1, 1, 256)    4352        ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multiply)   (None, 24, 24, 256)  0           ['block4a_activation[0][0]',
#                                                                   'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv2D)  (None, 24, 24, 128)  32768       ['block4a_se_excite[0][0]']
#
#  block4a_project_bn (BatchNorma  (None, 24, 24, 128)  512        ['block4a_project_conv[0][0]']
#  lization)
#
#  block4b_expand_conv (Conv2D)   (None, 24, 24, 512)  65536       ['block4a_project_bn[0][0]']
#
#  block4b_expand_bn (BatchNormal  (None, 24, 24, 512)  2048       ['block4b_expand_conv[0][0]']
#  ization)
#
#  block4b_expand_activation (Act  (None, 24, 24, 512)  0          ['block4b_expand_bn[0][0]']
#  ivation)
#
#  block4b_dwconv2 (DepthwiseConv  (None, 24, 24, 512)  4608       ['block4b_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4b_bn (BatchNormalization  (None, 24, 24, 512)  2048       ['block4b_dwconv2[0][0]']
#  )
#
#  block4b_activation (Activation  (None, 24, 24, 512)  0          ['block4b_bn[0][0]']
#  )
#
#  block4b_se_squeeze (GlobalAver  (None, 512)         0           ['block4b_activation[0][0]']
#  agePooling2D)
#
#  block4b_se_reshape (Reshape)   (None, 1, 1, 512)    0           ['block4b_se_squeeze[0][0]']
#
#  block4b_se_reduce (Conv2D)     (None, 1, 1, 32)     16416       ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)     (None, 1, 1, 512)    16896       ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multiply)   (None, 24, 24, 512)  0           ['block4b_activation[0][0]',
#                                                                   'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv2D)  (None, 24, 24, 128)  65536       ['block4b_se_excite[0][0]']
#
#  block4b_project_bn (BatchNorma  (None, 24, 24, 128)  512        ['block4b_project_conv[0][0]']
#  lization)
#
#  block4b_drop (Dropout)         (None, 24, 24, 128)  0           ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)              (None, 24, 24, 128)  0           ['block4b_drop[0][0]',
#                                                                   'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2D)   (None, 24, 24, 512)  65536       ['block4b_add[0][0]']
#
#  block4c_expand_bn (BatchNormal  (None, 24, 24, 512)  2048       ['block4c_expand_conv[0][0]']
#  ization)
#
#  block4c_expand_activation (Act  (None, 24, 24, 512)  0          ['block4c_expand_bn[0][0]']
#  ivation)
#
#  block4c_dwconv2 (DepthwiseConv  (None, 24, 24, 512)  4608       ['block4c_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4c_bn (BatchNormalization  (None, 24, 24, 512)  2048       ['block4c_dwconv2[0][0]']
#  )
#
#  block4c_activation (Activation  (None, 24, 24, 512)  0          ['block4c_bn[0][0]']
#  )
#
#  block4c_se_squeeze (GlobalAver  (None, 512)         0           ['block4c_activation[0][0]']
#  agePooling2D)
#
#  block4c_se_reshape (Reshape)   (None, 1, 1, 512)    0           ['block4c_se_squeeze[0][0]']
#
#  block4c_se_reduce (Conv2D)     (None, 1, 1, 32)     16416       ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)     (None, 1, 1, 512)    16896       ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multiply)   (None, 24, 24, 512)  0           ['block4c_activation[0][0]',
#                                                                   'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv2D)  (None, 24, 24, 128)  65536       ['block4c_se_excite[0][0]']
#
#  block4c_project_bn (BatchNorma  (None, 24, 24, 128)  512        ['block4c_project_conv[0][0]']
#  lization)
#
#  block4c_drop (Dropout)         (None, 24, 24, 128)  0           ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)              (None, 24, 24, 128)  0           ['block4c_drop[0][0]',
#                                                                   'block4b_add[0][0]']
#
#  block4d_expand_conv (Conv2D)   (None, 24, 24, 512)  65536       ['block4c_add[0][0]']
#
#  block4d_expand_bn (BatchNormal  (None, 24, 24, 512)  2048       ['block4d_expand_conv[0][0]']
#  ization)
#
#  block4d_expand_activation (Act  (None, 24, 24, 512)  0          ['block4d_expand_bn[0][0]']
#  ivation)
#
#  block4d_dwconv2 (DepthwiseConv  (None, 24, 24, 512)  4608       ['block4d_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4d_bn (BatchNormalization  (None, 24, 24, 512)  2048       ['block4d_dwconv2[0][0]']
#  )
#
#  block4d_activation (Activation  (None, 24, 24, 512)  0          ['block4d_bn[0][0]']
#  )
#
#  block4d_se_squeeze (GlobalAver  (None, 512)         0           ['block4d_activation[0][0]']
#  agePooling2D)
#
#  block4d_se_reshape (Reshape)   (None, 1, 1, 512)    0           ['block4d_se_squeeze[0][0]']
#
#  block4d_se_reduce (Conv2D)     (None, 1, 1, 32)     16416       ['block4d_se_reshape[0][0]']
#
#  block4d_se_expand (Conv2D)     (None, 1, 1, 512)    16896       ['block4d_se_reduce[0][0]']
#
#  block4d_se_excite (Multiply)   (None, 24, 24, 512)  0           ['block4d_activation[0][0]',
#                                                                   'block4d_se_expand[0][0]']
#
#  block4d_project_conv (Conv2D)  (None, 24, 24, 128)  65536       ['block4d_se_excite[0][0]']
#
#  block4d_project_bn (BatchNorma  (None, 24, 24, 128)  512        ['block4d_project_conv[0][0]']
#  lization)
#
#  block4d_drop (Dropout)         (None, 24, 24, 128)  0           ['block4d_project_bn[0][0]']
#
#  block4d_add (Add)              (None, 24, 24, 128)  0           ['block4d_drop[0][0]',
#                                                                   'block4c_add[0][0]']
#
#  block4e_expand_conv (Conv2D)   (None, 24, 24, 512)  65536       ['block4d_add[0][0]']
#
#  block4e_expand_bn (BatchNormal  (None, 24, 24, 512)  2048       ['block4e_expand_conv[0][0]']
#  ization)
#
#  block4e_expand_activation (Act  (None, 24, 24, 512)  0          ['block4e_expand_bn[0][0]']
#  ivation)
#
#  block4e_dwconv2 (DepthwiseConv  (None, 24, 24, 512)  4608       ['block4e_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4e_bn (BatchNormalization  (None, 24, 24, 512)  2048       ['block4e_dwconv2[0][0]']
#  )
#
#  block4e_activation (Activation  (None, 24, 24, 512)  0          ['block4e_bn[0][0]']
#  )
#
#  block4e_se_squeeze (GlobalAver  (None, 512)         0           ['block4e_activation[0][0]']
#  agePooling2D)
#
#  block4e_se_reshape (Reshape)   (None, 1, 1, 512)    0           ['block4e_se_squeeze[0][0]']
#
#  block4e_se_reduce (Conv2D)     (None, 1, 1, 32)     16416       ['block4e_se_reshape[0][0]']
#
#  block4e_se_expand (Conv2D)     (None, 1, 1, 512)    16896       ['block4e_se_reduce[0][0]']
#
#  block4e_se_excite (Multiply)   (None, 24, 24, 512)  0           ['block4e_activation[0][0]',
#                                                                   'block4e_se_expand[0][0]']
#
#  block4e_project_conv (Conv2D)  (None, 24, 24, 128)  65536       ['block4e_se_excite[0][0]']
#
#  block4e_project_bn (BatchNorma  (None, 24, 24, 128)  512        ['block4e_project_conv[0][0]']
#  lization)
#
#  block4e_drop (Dropout)         (None, 24, 24, 128)  0           ['block4e_project_bn[0][0]']
#
#  block4e_add (Add)              (None, 24, 24, 128)  0           ['block4e_drop[0][0]',
#                                                                   'block4d_add[0][0]']
#
#  block4f_expand_conv (Conv2D)   (None, 24, 24, 512)  65536       ['block4e_add[0][0]']
#
#  block4f_expand_bn (BatchNormal  (None, 24, 24, 512)  2048       ['block4f_expand_conv[0][0]']
#  ization)
#
#  block4f_expand_activation (Act  (None, 24, 24, 512)  0          ['block4f_expand_bn[0][0]']
#  ivation)
#
#  block4f_dwconv2 (DepthwiseConv  (None, 24, 24, 512)  4608       ['block4f_expand_activation[0][0]
#  2D)                                                             ']
#
#  block4f_bn (BatchNormalization  (None, 24, 24, 512)  2048       ['block4f_dwconv2[0][0]']
#  )
#
#  block4f_activation (Activation  (None, 24, 24, 512)  0          ['block4f_bn[0][0]']
#  )
#
#  block4f_se_squeeze (GlobalAver  (None, 512)         0           ['block4f_activation[0][0]']
#  agePooling2D)
#
#  block4f_se_reshape (Reshape)   (None, 1, 1, 512)    0           ['block4f_se_squeeze[0][0]']
#
#  block4f_se_reduce (Conv2D)     (None, 1, 1, 32)     16416       ['block4f_se_reshape[0][0]']
#
#  block4f_se_expand (Conv2D)     (None, 1, 1, 512)    16896       ['block4f_se_reduce[0][0]']
#
#  block4f_se_excite (Multiply)   (None, 24, 24, 512)  0           ['block4f_activation[0][0]',
#                                                                   'block4f_se_expand[0][0]']
#
#  block4f_project_conv (Conv2D)  (None, 24, 24, 128)  65536       ['block4f_se_excite[0][0]']
#
#  block4f_project_bn (BatchNorma  (None, 24, 24, 128)  512        ['block4f_project_conv[0][0]']
#  lization)
#
#  block4f_drop (Dropout)         (None, 24, 24, 128)  0           ['block4f_project_bn[0][0]']
#
#  block4f_add (Add)              (None, 24, 24, 128)  0           ['block4f_drop[0][0]',
#                                                                   'block4e_add[0][0]']
#
#  block5a_expand_conv (Conv2D)   (None, 24, 24, 768)  98304       ['block4f_add[0][0]']
#
#  block5a_expand_bn (BatchNormal  (None, 24, 24, 768)  3072       ['block5a_expand_conv[0][0]']
#  ization)
#
#  block5a_expand_activation (Act  (None, 24, 24, 768)  0          ['block5a_expand_bn[0][0]']
#  ivation)
#
#  block5a_dwconv2 (DepthwiseConv  (None, 24, 24, 768)  6912       ['block5a_expand_activation[0][0]
#  2D)                                                             ']
#
#  block5a_bn (BatchNormalization  (None, 24, 24, 768)  3072       ['block5a_dwconv2[0][0]']
#  )
#
#  block5a_activation (Activation  (None, 24, 24, 768)  0          ['block5a_bn[0][0]']
#  )
#
#  block5a_se_squeeze (GlobalAver  (None, 768)         0           ['block5a_activation[0][0]']
#  agePooling2D)
#
#  block5a_se_reshape (Reshape)   (None, 1, 1, 768)    0           ['block5a_se_squeeze[0][0]']
#
#  block5a_se_reduce (Conv2D)     (None, 1, 1, 32)     24608       ['block5a_se_reshape[0][0]']
#
#  block5a_se_expand (Conv2D)     (None, 1, 1, 768)    25344       ['block5a_se_reduce[0][0]']
#
#  block5a_se_excite (Multiply)   (None, 24, 24, 768)  0           ['block5a_activation[0][0]',
#                                                                   'block5a_se_expand[0][0]']
#
#  block5a_project_conv (Conv2D)  (None, 24, 24, 160)  122880      ['block5a_se_excite[0][0]']
#
#  block5a_project_bn (BatchNorma  (None, 24, 24, 160)  640        ['block5a_project_conv[0][0]']
#  lization)
#
#  block5b_expand_conv (Conv2D)   (None, 24, 24, 960)  153600      ['block5a_project_bn[0][0]']
#
#  block5b_expand_bn (BatchNormal  (None, 24, 24, 960)  3840       ['block5b_expand_conv[0][0]']
#  ization)
#
#  block5b_expand_activation (Act  (None, 24, 24, 960)  0          ['block5b_expand_bn[0][0]']
#  ivation)
#
#  block5b_dwconv2 (DepthwiseConv  (None, 24, 24, 960)  8640       ['block5b_expand_activation[0][0]
#  2D)                                                             ']
#
#  block5b_bn (BatchNormalization  (None, 24, 24, 960)  3840       ['block5b_dwconv2[0][0]']
#  )
#
#  block5b_activation (Activation  (None, 24, 24, 960)  0          ['block5b_bn[0][0]']
#  )
#
#  block5b_se_squeeze (GlobalAver  (None, 960)         0           ['block5b_activation[0][0]']
#  agePooling2D)
#
#  block5b_se_reshape (Reshape)   (None, 1, 1, 960)    0           ['block5b_se_squeeze[0][0]']
#
#  block5b_se_reduce (Conv2D)     (None, 1, 1, 40)     38440       ['block5b_se_reshape[0][0]']
#
#  block5b_se_expand (Conv2D)     (None, 1, 1, 960)    39360       ['block5b_se_reduce[0][0]']
#
#  block5b_se_excite (Multiply)   (None, 24, 24, 960)  0           ['block5b_activation[0][0]',
#                                                                   'block5b_se_expand[0][0]']
#
#  block5b_project_conv (Conv2D)  (None, 24, 24, 160)  153600      ['block5b_se_excite[0][0]']
#
#  block5b_project_bn (BatchNorma  (None, 24, 24, 160)  640        ['block5b_project_conv[0][0]']
#  lization)
#
# ...
#  block6l_se_squeeze (GlobalAver  (None, 1536)        0           ['block6l_activation[0][0]']
#  agePooling2D)
#
#  block6l_se_reshape (Reshape)   (None, 1, 1, 1536)   0           ['block6l_se_squeeze[0][0]']
#
#  block6l_se_reduce (Conv2D)     (None, 1, 1, 64)     98368       ['block6l_se_reshape[0][0]']
#
#  block6l_se_expand (Conv2D)     (None, 1, 1, 1536)   99840       ['block6l_se_reduce[0][0]']
#
#  block6l_se_excite (Multiply)   (None, 12, 12, 1536  0           ['block6l_activation[0][0]',
#                                 )                                 'block6l_se_expand[0][0]']
#
#  block6l_project_conv (Conv2D)  (None, 12, 12, 256)  393216      ['block6l_se_excite[0][0]']
#
#  block6l_project_bn (BatchNorma  (None, 12, 12, 256)  1024       ['block6l_project_conv[0][0]']
#  lization)
#
#  block6l_drop (Dropout)         (None, 12, 12, 256)  0           ['block6l_project_bn[0][0]']
#
#  block6l_add (Add)              (None, 12, 12, 256)  0           ['block6l_drop[0][0]',
#                                                                   'block6k_add[0][0]']
#
#  block6m_expand_conv (Conv2D)   (None, 12, 12, 1536  393216      ['block6l_add[0][0]']
#                                 )
#
#  block6m_expand_bn (BatchNormal  (None, 12, 12, 1536  6144       ['block6m_expand_conv[0][0]']
#  ization)                       )
#
#  block6m_expand_activation (Act  (None, 12, 12, 1536  0          ['block6m_expand_bn[0][0]']
#  ivation)                       )
#
#  block6m_dwconv2 (DepthwiseConv  (None, 12, 12, 1536  13824      ['block6m_expand_activation[0][0]
#  2D)                            )                                ']
#
#  block6m_bn (BatchNormalization  (None, 12, 12, 1536  6144       ['block6m_dwconv2[0][0]']
#  )                              )
#
#  block6m_activation (Activation  (None, 12, 12, 1536  0          ['block6m_bn[0][0]']
#  )                              )
#
#  block6m_se_squeeze (GlobalAver  (None, 1536)        0           ['block6m_activation[0][0]']
#  agePooling2D)
#
#  block6m_se_reshape (Reshape)   (None, 1, 1, 1536)   0           ['block6m_se_squeeze[0][0]']
#
#  block6m_se_reduce (Conv2D)     (None, 1, 1, 64)     98368       ['block6m_se_reshape[0][0]']
#
#  block6m_se_expand (Conv2D)     (None, 1, 1, 1536)   99840       ['block6m_se_reduce[0][0]']
#
#  block6m_se_excite (Multiply)   (None, 12, 12, 1536  0           ['block6m_activation[0][0]',
#                                 )                                 'block6m_se_expand[0][0]']
#
#  block6m_project_conv (Conv2D)  (None, 12, 12, 256)  393216      ['block6m_se_excite[0][0]']
#
#  block6m_project_bn (BatchNorma  (None, 12, 12, 256)  1024       ['block6m_project_conv[0][0]']
#  lization)
#
#  block6m_drop (Dropout)         (None, 12, 12, 256)  0           ['block6m_project_bn[0][0]']
#
#  block6m_add (Add)              (None, 12, 12, 256)  0           ['block6m_drop[0][0]',
#                                                                   'block6l_add[0][0]']
#
#  block6n_expand_conv (Conv2D)   (None, 12, 12, 1536  393216      ['block6m_add[0][0]']
#                                 )
#
#  block6n_expand_bn (BatchNormal  (None, 12, 12, 1536  6144       ['block6n_expand_conv[0][0]']
#  ization)                       )
#
#  block6n_expand_activation (Act  (None, 12, 12, 1536  0          ['block6n_expand_bn[0][0]']
#  ivation)                       )
#
#  block6n_dwconv2 (DepthwiseConv  (None, 12, 12, 1536  13824      ['block6n_expand_activation[0][0]
#  2D)                            )                                ']
#
#  block6n_bn (BatchNormalization  (None, 12, 12, 1536  6144       ['block6n_dwconv2[0][0]']
#  )                              )
#
#  block6n_activation (Activation  (None, 12, 12, 1536  0          ['block6n_bn[0][0]']
#  )                              )
#
#  block6n_se_squeeze (GlobalAver  (None, 1536)        0           ['block6n_activation[0][0]']
#  agePooling2D)
#
#  block6n_se_reshape (Reshape)   (None, 1, 1, 1536)   0           ['block6n_se_squeeze[0][0]']
#
#  block6n_se_reduce (Conv2D)     (None, 1, 1, 64)     98368       ['block6n_se_reshape[0][0]']
#
#  block6n_se_expand (Conv2D)     (None, 1, 1, 1536)   99840       ['block6n_se_reduce[0][0]']
#
#  block6n_se_excite (Multiply)   (None, 12, 12, 1536  0           ['block6n_activation[0][0]',
#                                 )                                 'block6n_se_expand[0][0]']
#
#  block6n_project_conv (Conv2D)  (None, 12, 12, 256)  393216      ['block6n_se_excite[0][0]']
#
#  block6n_project_bn (BatchNorma  (None, 12, 12, 256)  1024       ['block6n_project_conv[0][0]']
#  lization)
#
#  block6n_drop (Dropout)         (None, 12, 12, 256)  0           ['block6n_project_bn[0][0]']
#
#  block6n_add (Add)              (None, 12, 12, 256)  0           ['block6n_drop[0][0]',
#                                                                   'block6m_add[0][0]']
#
#  block6o_expand_conv (Conv2D)   (None, 12, 12, 1536  393216      ['block6n_add[0][0]']
#                                 )
#
#  block6o_expand_bn (BatchNormal  (None, 12, 12, 1536  6144       ['block6o_expand_conv[0][0]']
#  ization)                       )
#
#  block6o_expand_activation (Act  (None, 12, 12, 1536  0          ['block6o_expand_bn[0][0]']
#  ivation)                       )
#
#  block6o_dwconv2 (DepthwiseConv  (None, 12, 12, 1536  13824      ['block6o_expand_activation[0][0]
#  2D)                            )                                ']
#
#  block6o_bn (BatchNormalization  (None, 12, 12, 1536  6144       ['block6o_dwconv2[0][0]']
#  )                              )
#
#  block6o_activation (Activation  (None, 12, 12, 1536  0          ['block6o_bn[0][0]']
#  )                              )
#
#  block6o_se_squeeze (GlobalAver  (None, 1536)        0           ['block6o_activation[0][0]']
#  agePooling2D)
#
#  block6o_se_reshape (Reshape)   (None, 1, 1, 1536)   0           ['block6o_se_squeeze[0][0]']
#
#  block6o_se_reduce (Conv2D)     (None, 1, 1, 64)     98368       ['block6o_se_reshape[0][0]']
#
#  block6o_se_expand (Conv2D)     (None, 1, 1, 1536)   99840       ['block6o_se_reduce[0][0]']
#
#  block6o_se_excite (Multiply)   (None, 12, 12, 1536  0           ['block6o_activation[0][0]',
#                                 )                                 'block6o_se_expand[0][0]']
#
#  block6o_project_conv (Conv2D)  (None, 12, 12, 256)  393216      ['block6o_se_excite[0][0]']
#
#  block6o_project_bn (BatchNorma  (None, 12, 12, 256)  1024       ['block6o_project_conv[0][0]']
#  lization)
#
#  block6o_drop (Dropout)         (None, 12, 12, 256)  0           ['block6o_project_bn[0][0]']
#
#  block6o_add (Add)              (None, 12, 12, 256)  0           ['block6o_drop[0][0]',
#                                                                   'block6n_add[0][0]']
#
#  top_conv (Conv2D)              (None, 12, 12, 1280  327680      ['block6o_add[0][0]']
#                                 )
#
#  top_bn (BatchNormalization)    (None, 12, 12, 1280  5120        ['top_conv[0][0]']
#                                 )
#
#  top_activation (Activation)    (None, 12, 12, 1280  0           ['top_bn[0][0]']
#                                 )
#
#  avg_pool (GlobalAveragePooling  (None, 1280)        0           ['top_activation[0][0]']
#  2D)
#
#  top_dropout (Dropout)          (None, 1280)         0           ['avg_pool[0][0]']
#
#  my_predictions (Dense)         (None, 2)            2562        ['top_dropout[0][0]']
#
# ==================================================================================================
# Total params: 20,333,922
# Trainable params: 20,180,050
# Non-trainable params: 153,872
# __________________________________________________________________________________________________
# None

# %%
# ModelCheckpoint callback - save best weights
estopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=30)
checkpoint = ModelCheckpoint(filepath='/content/drive/MyDrive/Mestrado/Experimentos/exp-retina/exp-retina-pynb/model_efficientnetv2s_rdn.weights.best.hdf5', save_best_only=True, verbose=0)
history = EfficientNetV2S_model.fit(x_train1, y_train, epochs=100, batch_size=16, verbose=1, shuffle=True, validation_split=0.1, callbacks=[checkpoint, estopping])
# Out:
# Epoch 1/100
# 17/17 [==============================] - 60s 2s/step - loss: 0.7958 - accuracy: 0.4667 - val_loss: 0.6759 - val_accuracy: 0.6000
# Epoch 2/100
# 17/17 [==============================] - 11s 623ms/step - loss: 0.6233 - accuracy: 0.7259 - val_loss: 0.7150 - val_accuracy: 0.6000
# Epoch 3/100
# 17/17 [==============================] - 11s 628ms/step - loss: 0.5725 - accuracy: 0.7667 - val_loss: 0.6914 - val_accuracy: 0.6000
# Epoch 4/100
# 17/17 [==============================] - 21s 1s/step - loss: 0.5081 - accuracy: 0.7926 - val_loss: 0.6751 - val_accuracy: 0.6000
# Epoch 5/100
# 17/17 [==============================] - 22s 1s/step - loss: 0.4639 - accuracy: 0.7963 - val_loss: 0.6679 - val_accuracy: 0.6333
# Epoch 6/100
# 17/17 [==============================] - 11s 643ms/step - loss: 0.4737 - accuracy: 0.8074 - val_loss: 2.3690 - val_accuracy: 0.6667
# Epoch 7/100
# 17/17 [==============================] - 11s 650ms/step - loss: 0.4866 - accuracy: 0.8148 - val_loss: 3.4957 - val_accuracy: 0.7000
# Epoch 8/100
# 17/17 [==============================] - 21s 1s/step - loss: 0.4359 - accuracy: 0.8148 - val_loss: 0.5323 - val_accuracy: 0.7667
# Epoch 9/100
# 17/17 [==============================] - 11s 658ms/step - loss: 0.4185 - accuracy: 0.8259 - val_loss: 0.6027 - val_accuracy: 0.6667
# Epoch 10/100
# 17/17 [==============================] - 22s 1s/step - loss: 0.3700 - accuracy: 0.8333 - val_loss: 0.3982 - val_accuracy: 0.8333
# Epoch 11/100
# 17/17 [==============================] - 11s 652ms/step - loss: 0.3679 - accuracy: 0.8667 - val_loss: 0.4004 - val_accuracy: 0.8000
# Epoch 12/100
# 17/17 [==============================] - 11s 659ms/step - loss: 0.3033 - accuracy: 0.8815 - val_loss: 0.5677 - val_accuracy: 0.7667
# Epoch 13/100
# 17/17 [==============================] - 11s 659ms/step - loss: 0.2868 - accuracy: 0.8815 - val_loss: 1.1793 - val_accuracy: 0.7333
# Epoch 14/100
# 17/17 [==============================] - 11s 655ms/step - loss: 0.2074 - accuracy: 0.9333 - val_loss: 0.6413 - val_accuracy: 0.7667
# Epoch 15/100
# 17/17 [==============================] - 11s 655ms/step - loss: 0.2595 - accuracy: 0.9111 - val_loss: 0.7218 - val_accuracy: 0.7667
# Epoch 16/100
# 17/17 [==============================] - 11s 655ms/step - loss: 0.2159 - accuracy: 0.9222 - val_loss: 0.7586 - val_accuracy: 0.7000
# Epoch 17/100
# 17/17 [==============================] - 11s 653ms/step - loss: 0.2157 - accuracy: 0.9148 - val_loss: 0.7331 - val_accuracy: 0.7667
# Epoch 18/100
# 17/17 [==============================] - 11s 655ms/step - loss: 0.2140 - accuracy: 0.9185 - val_loss: 0.4540 - val_accuracy: 0.8667
# Epoch 19/100
# 17/17 [==============================] - 11s 656ms/step - loss: 0.2762 - accuracy: 0.8741 - val_loss: 0.4949 - val_accuracy: 0.8333
# Epoch 20/100
# 17/17 [==============================] - 11s 657ms/step - loss: 0.2171 - accuracy: 0.9000 - val_loss: 0.4262 - val_accuracy: 0.8333
# Epoch 21/100
# 17/17 [==============================] - 11s 659ms/step - loss: 0.1941 - accuracy: 0.9333 - val_loss: 0.4910 - val_accuracy: 0.7667
# Epoch 22/100
# 17/17 [==============================] - 11s 657ms/step - loss: 0.1849 - accuracy: 0.9333 - val_loss: 0.4841 - val_accuracy: 0.8000
# Epoch 23/100
# 17/17 [==============================] - 11s 656ms/step - loss: 0.2508 - accuracy: 0.9037 - val_loss: 0.4576 - val_accuracy: 0.8333
# Epoch 24/100
# 17/17 [==============================] - 11s 657ms/step - loss: 0.1421 - accuracy: 0.9556 - val_loss: 0.5106 - val_accuracy: 0.7333
# Epoch 25/100
# 17/17 [==============================] - 11s 656ms/step - loss: 0.1174 - accuracy: 0.9667 - val_loss: 0.7251 - val_accuracy: 0.7667
# Epoch 26/100
# 17/17 [==============================] - 11s 656ms/step - loss: 0.1592 - accuracy: 0.9519 - val_loss: 0.5638 - val_accuracy: 0.8000
# Epoch 27/100
# 17/17 [==============================] - 11s 656ms/step - loss: 0.1614 - accuracy: 0.9481 - val_loss: 0.6766 - val_accuracy: 0.7333
# Epoch 28/100
# 17/17 [==============================] - 11s 654ms/step - loss: 0.1647 - accuracy: 0.9333 - val_loss: 0.5512 - val_accuracy: 0.8000
# Epoch 29/100
# 17/17 [==============================] - 11s 657ms/step - loss: 0.1691 - accuracy: 0.9148 - val_loss: 0.4620 - val_accuracy: 0.9000
# Epoch 30/100
# 17/17 [==============================] - 11s 656ms/step - loss: 0.1827 - accuracy: 0.9222 - val_loss: 0.3988 - val_accuracy: 0.8000
# Epoch 31/100
# 17/17 [==============================] - 11s 657ms/step - loss: 0.0998 - accuracy: 0.9704 - val_loss: 0.6570 - val_accuracy: 0.8333
# Epoch 32/100
# 17/17 [==============================] - 11s 656ms/step - loss: 0.1316 - accuracy: 0.9593 - val_loss: 0.4810 - val_accuracy: 0.8000
# Epoch 33/100
# 17/17 [==============================] - 11s 656ms/step - loss: 0.1789 - accuracy: 0.9333 - val_loss: 0.6445 - val_accuracy: 0.7667
# Epoch 34/100
# 17/17 [==============================] - 11s 655ms/step - loss: 0.1312 - accuracy: 0.9556 - val_loss: 0.6586 - val_accuracy: 0.8000
# Epoch 35/100
# 17/17 [==============================] - 11s 656ms/step - loss: 0.0670 - accuracy: 0.9741 - val_loss: 0.6819 - val_accuracy: 0.8000
# Epoch 36/100
# 17/17 [==============================] - 11s 655ms/step - loss: 0.0818 - accuracy: 0.9704 - val_loss: 0.7429 - val_accuracy: 0.7333
# Epoch 37/100
# 17/17 [==============================] - 11s 657ms/step - loss: 0.0948 - accuracy: 0.9556 - val_loss: 0.7631 - val_accuracy: 0.8000
# Epoch 38/100
# 17/17 [==============================] - 11s 656ms/step - loss: 0.1050 - accuracy: 0.9593 - val_loss: 0.6874 - val_accuracy: 0.8000
# Epoch 39/100
# 17/17 [==============================] - 11s 655ms/step - loss: 0.0916 - accuracy: 0.9630 - val_loss: 0.5046 - val_accuracy: 0.8333
# Epoch 40/100
# 17/17 [==============================] - 11s 656ms/step - loss: 0.0837 - accuracy: 0.9741 - val_loss: 0.6307 - val_accuracy: 0.8333

# %%
plt.figure(figsize=(12,4))
plt.subplot(121), plt.plot(history.history['loss'], label='loss')
plt.subplot(121), plt.plot(history.history['val_loss'], label='val_loss')
plt.xlabel('Época', fontsize=12), plt.ylabel('Loss', fontsize=12)
plt.title('Evolução da curva de perda')
plt.legend()
plt.subplot(122), plt.plot(history.history['accuracy'], label = 'accuracy', color='green')
plt.subplot(122), plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Época', fontsize=12), plt.ylabel('Acc', fontsize=12)
plt.title('Evolução da curva de acurácia')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
### TEST ACC ###
scores = EfficientNetV2S_model.evaluate(x_test1, y_test)
print('\n%s : %.2f%%' % (EfficientNetV2S_model.metrics_names[1], scores[1] * 100))
# Out:
# 4/4 [==============================] - 3s 470ms/step - loss: 0.5382 - accuracy: 0.8800
#
# accuracy : 88.00%
